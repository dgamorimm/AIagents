# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# Carregar variáveis de ambiente
load_dotenv()
chat = ChatOpenAI(api_key = os.getenv("OPENAI_API_KEY"),
                  model="gpt-5-mini", temperature=0.7)

# %% [markdown]
# ### Trabalhando com LLMs e ChatModels no LangChain
# - O LangChain fornece uma interface padronizada para conectar diferentes Modelos de Linguagem (LLMs).
# - Hoje a forma recomendada é trabalhar com **ChatModels**, que suportam tanto prompts simples quanto interações mais complexas baseadas em mensagens.

# %% [markdown]
# ### Exemplo 1 - Prompt Simples
# - Usando apenas texto, sem mensagens estruturadas

# %%
resposta = chat.invoke("Me conte uma piada curta sobre programadores.")
print(resposta.content)
# Out:
# Por que o programador confunde Halloween com Natal? Porque Oct 31 = Dec 25.

# %% [markdown]
# ### Exemplo 2 - Resposta em Streaming

# %%
prompt = "Escreva uma história de aventura em 3 parágrafos, com cliffhangers."
for chunk in chat.stream(prompt):
    print(chunk.content, end="", flush=True)
# Out:
# Marina encontrou o mapa escondido entre as tábuas podres do sótão da casa do avô, enrolado num pergaminho amarelado e marcado com a palavra Ilhabela e um símbolo que parecia um olho. Ela nunca tinha saído da pequena vila de pescadores, mas a obsessão por histórias antigas a empurrou a convencer o irmão, Diego, a alugar um barco e seguir rumo à neblina que escondia a linha do horizonte. Quando a costa da ilha surgiu como um recorte escuro contra o sol morno, eles perceberam que não eram os únicos a conhecer aquele segredo: eram três sombras em pé na praia, observando-os, e uma delas acenou como se já os esperasse...
#
# A mata engoliu o calor e o som do mar logo após os primeiros passos; cipós pendiam como cordas sobre trilhas que desapareciam em pastos de samambaias. Seguindo as marcas do mapa — setas riscadas, um símbolo de pétalas, uma sequência de números — eles chegaram a ruínas cobertas de musgo, obeliscos alinhados como guardiões de pedra. No centro jazia uma entrada baixa, selada por uma laje com o mesmo olho do mapa, e, ao tocá-la, sentiram um tremor que veio das profundezas. Antes que pudessem recuar, ouviram, lá embaixo, um som ritmado que lembrava batimentos de um coração, e algo riscou a superfície da pedra por dentro, como se quisesse sair...
#
# A laje cedeu, derramando umidade fria e um cheiro de metal antigo, e eles desceram por uma escada que se iluminava com veios de cristal azul que pulsavam acompanhando o som. No fundo, uma câmara colossal abrigava o que parecia ser um coração de pedra suspenso por correntes de luz, rodeado por altares onde símbolos entalhados brilhavam com uma lua própria. As sombras da praia estavam ali também, com rostos expostos pela primeira vez — não eram humanos como eles, mas guardiões esculpidos em carne — e, quando Diego estendeu a mão para tocar o coração, as correntes estalaram e a pedra começou a despertar, liberando uma vibração que fez as paredes racharem e um vento que trouxe uma voz antiga sussurrando seu nome...

# %% [markdown]
# ### Exemplo 3 – Batch
# - Enviando várias perguntas de uma vez

# %%
perguntas = [
    "O que é Memória RAM?",
    "Explique o papel da Memória Cache.",
    "Qual a função do Processador?"
]
respostas = chat.batch(perguntas)

for pergunta, resposta in zip(perguntas, respostas):
    print(f"\n❓ {pergunta}")
    print(f"💡 {resposta.content}")
# Out:
# ❓ O que é Memória RAM?
# 💡 Memória RAM (Random Access Memory) é a memória de trabalho do computador — o espaço rápido e temporário onde o processador guarda dados e instruções que estão sendo usados no momento. Características principais:
#
# - Volátil: perde o conteúdo quando o computador é desligado (ao contrário de HD/SSD, que são persistentes).
# - Acesso aleatório: o processador pode ler/escrever diretamente em qualquer posição da RAM com latência baixa.
# - Muito mais rápida que o armazenamento permanente, por isso programas e dados ativos são carregados da unidade (HD/SSD) para a RAM para execução.
#
# Tipos e tecnologia
# - SRAM (Static RAM): muito rápida, usada em caches de CPU; não é usada como memória principal por ser cara.
# - DRAM (Dynamic RAM): usada como memória principal dos PCs. Hoje em dia existem gerações DDR (DDR3, DDR4, DDR5) com diferentes velocidades e latências. Para laptops existem módulos SODIMM.
#
# Como afeta desempenho
# - Quantidade (GB) determina quantos programas e dados podem ficar “na memória” ao mesmo tempo. Pouca RAM faz o sistema usar disco (swap/paging), deixando tudo muito mais lento.
# - Velocidade (MHz/MT/s) e latência (CAS) influenciam a rapidez de acesso; ganhos práticos variam conforme aplicação.
# - Dual/quad channel (usar pares/sets idênticos) pode aumentar a largura de banda.
#
# Quando é suficiente
# - Uso leve (navegar, escritório): 8 GB costuma ser mínimo hoje.
# - Uso geral/gaming: 16 GB recomendado.
# - Edição de vídeo, modelagem 3D, máquinas virtuais: 32 GB ou mais.
#
# Outros pontos úteis
# - Compatibilidade: placa-mãe e CPU definem tipo (DDR4/DDR5), velocidade máxima e capacidade por slot.
# - ECC vs non-ECC: ECC corrige erros (usado em servidores/profissional).
# - Upgrades: prefira módulos combináveis (mesma capacidade/freq.), usar os slots em pares para aproveitar dual channel.
#
# Analogamente: se o disco é um arquivo grande de materiais e a CPU é uma pessoa trabalhando, a RAM é a mesa onde essa pessoa coloca os papéis abertos. Mesa maior = cabe mais trabalho simultâneo.
#
# Se quiser, posso:
# - Verificar qual memória sua placa-mãe/PC suporta (dizendo modelo).
# - Ajudar a escolher um módulo compatível para upgrade.
#
# ❓ Explique o papel da Memória Cache.
# 💡 A memória cache é uma pequena memória muito rápida colocada entre a CPU e a memória principal (RAM) cujo papel é reduzir a latência de acesso a dados e instruções usados frequentemente, melhorando sensivelmente o desempenho do sistema.
#
# Principais funções
# - Guardar temporariamente blocos de dados e instruções acessados recentemente ou próximos uns dos outros, para que a CPU os leia/escreva mais rapidamente do que acessando a RAM.
# - Reduzir o tempo médio de acesso à memória e a frequência de esperas da CPU.
#
# Princípios de funcionamento
# - Localidade temporal: dados/instruções acessados agora têm maior probabilidade de ser acessados novamente em breve.
# - Localidade espacial: se um endereço é acessado, probabilidade grande de que endereços próximos também sejam acessados.
#
# Estrutura e operação
# - Blocos/linhas de cache: a memória é organizada em linhas que armazenam um bloco contíguo da RAM.
# - Tags: cada linha tem uma tag que identifica qual endereço da RAM está armazenado.
# - Hit: dado encontrado no cache → acesso rápido. Miss: dado não está no cache → busca na RAM (mais lenta) e carregamento para o cache.
# - Políticas de substituição: LRU, FIFO, Random, etc., definem qual linha substituir em caso de falta de espaço.
# - Políticas de escrita: write-through (escreve na RAM imediatamente) e write-back (escreve na RAM apenas quando a linha é substituída), com trade-offs de desempenho e complexidade.
#
# Tipos e hierarquia
# - Níveis: L1 (muito rápido, pequeno, normalmente separado para dados e instruções), L2 (maior, mais lento) e L3 (compartilhado entre núcleos, ainda maior). Vários níveis aumentam a probabilidade de hit antes de chegar à RAM.
# - Associatividade: direto, totalmente associativo, ou set-associativo (compromisso entre simplicidade e taxa de acerto).
#
# Métricas importantes
# - Taxa de acerto (hit rate) e de falta (miss rate).
# - Tempo de acesso ao cache (hit time) e penalidade de falta (miss penalty).
# - Tempo médio de acesso (AMAT) = hit time + miss rate × miss penalty.
#   Ex.: se hit time = 1 ns, miss rate = 5%, miss penalty = 50 ns → AMAT = 1 + 0,05×50 = 3,5 ns.
#
# Considerações adicionais
# - Em sistemas multicore, há necessidade de protocolos de coerência (ex.: MESI) para garantir consistência entre caches.
# - Trade-offs: caches maiores aumentam taxa de acerto mas são mais lentos e caros; latência, consumo e complexidade aumentam com associatividade e políticas sofisticadas.
#
# Resumo
# A memória cache atua como um intermediário rápido que explora a localidade dos programas para fornecer à CPU dados e instruções com menor latência, reduzindo o número de acessos diretos à RAM e, consequentemente, melhorando o desempenho geral do sistema.
#
# ❓ Qual a função do Processador?
# 💡 O processador (CPU — Unidade Central de Processamento) é o "cérebro" do computador. Sua função principal é executar instruções de programas e coordenar o funcionamento das outras partes do sistema. Resumindo, as funções mais importantes são:
#
# - Buscar e interpretar instruções (unidade de controlo) — lê códigos de programas da memória e decide o que fazer a seguir.
# - Executar operações aritméticas e lógicas (ALU) — soma, subtração, comparações, operações bit a bit, etc.
# - Gerir registos — armazenar temporariamente valores e endereços usados pelas instruções.
# - Controlar fluxos (decisões, saltos, chamadas de função) — altera a sequência de execução conforme o programa.
# - Tratar interrupções e comunicação com dispositivos — responde a eventos do sistema, I/O e periféricos.
# - Gerir acesso à memória e caches — otimizar leitura/escrita de dados para acelerar o processamento.
# - Trabalhar em paralelo (núcleos/threads) — executar várias tarefas simultaneamente em CPUs multicore.
#
# Fatores que influenciam o desempenho: frequência (GHz), número de núcleos e threads, tamanho do cache, microarquitetura (IPC), e eficiência do sistema de memória. Se quiser, explico mais sobre como escolher um processador, diferenças entre CPU e GPU, ou o que significam núcleos/threads.

# %% [markdown]
# ### Exemplo 4 – Chat estruturado
# - Usando mensagens de sistema e humano para controlar o estilo da resposta

# %% [markdown]
# ### Mensagens no LangChain
# - SystemMessage define o “papel” ou tom do modelo.
# - HumanMessage representa entradas do usuário.
# - AIMessage pode ser usado para simular histórico de conversas.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

# %%
mensagens = [
    SystemMessage(content="Você é um professor de tecnologia que responde com humor."),
    HumanMessage(content="Explique a diferença entre HD e SSD.")
]

resposta = chat.invoke(mensagens)
print(resposta.content)
# Out:
# Pense no HD (HDD) como um toca‑discos antigo: tem pratos girando e uma agulha que vai lá e pega a música. O SSD é como um pendrive superrápido e silencioso — sem partes móveis, só memória flash. Agora vamos às diferenças sem perder o bom humor (mas com ciência por trás).
#
# Principais diferenças
# - Como funcionam
#   - HDD: discos magnéticos girando e uma cabeça de leitura/escrita que se move. Mecânico.
#   - SSD: memória flash NAND, dados eletrônicos. Sem partes móveis.
# - Velocidade
#   - HDD: leitura/escrita sequencial lenta a moderada; desempenho ruim em acessos aleatórios (vários arquivos pequenos).
#   - SSD: muito mais rápido no boot, abertura de programas e I/O aleatório. NVMe SSDs são bem mais rápidos que SSDs SATA.
# - Latência
#   - HDD: latência maior por conta do movimento físico.
#   - SSD: latência muito baixa — tudo responde quase instantaneamente.
# - Ruído, calor e consumo
#   - HDD: faz barulho, vibra e consome mais energia em operação.
#   - SSD: silencioso, gera menos calor e consome menos energia.
# - Durabilidade e resistência física
#   - HDD: suscetível a choques/vibrações; cabeças podem danificar pratos.
#   - SSD: mais resistente a impactos. Mas tem limite de gravações (wear‑leveling controla isso).
# - Vida útil e escrita
#   - HDD: desgaste mecânico ao longo do tempo.
#   - SSD: tem limite de ciclos de escrita (TBW, DWPD). Para uso normal de desktop, a maioria dura muitos anos.
# - Custo e capacidade
#   - HDD: mais barato por GB; fácil achar 2–20 TB por preços baixos.
#   - SSD: mais caro por GB, embora preços tenham caído; ótimo para 250 GB–4 TB comuns.
# - Manutenção de software
#   - HDD: precisa de desfragmentação (em geral).
#   - SSD: não precisa desfragmentar; deve ter TRIM habilitado para manter desempenho.
#
# Interfaces importantes (rápido resumo)
# - SATA (2,5"): usado por HDDs e muitos SSDs; limite teórico ~600 MB/s.
# - NVMe (M.2 / PCIe): SSDs muito mais rápidos; Gen3 x4 ≈ 3–3,5 GB/s, Gen4 ≈ até ~7 GB/s (depende do drive).
#
# Quando escolher qual
# - Use SSD para: sistema operacional, programas/jogos e tarefas que precisam de rapidez (edição de vídeo, VM, desenvolvimento).
# - Use HDD para: backup, armazenamento em massa, arquivos que não precisam de acesso rápido (fotos antigas, vídeos brutos archievados).
# - Opção mista: SSD para o sistema + HDD grande para arquivos — a combinação mais sensata e frequentemente econômica.
#
# Dicas práticas (do prof. que já viu HD voar pela janela)
# - Ao trocar: clone o disco se quiser manter tudo, ou faça instalação limpa para melhor performance.
# - Ative TRIM no sistema operacional (Windows/Mac/Linux geralmente fazem isso automaticamente hoje).
# - Não desfragmente SSDs; só desperdiça ciclos de gravação.
# - Monitore SMART e TBW se precisar prever falhas.
# - Para notebooks, priorize SSD: melhora autonomia e resistência física.
#
# Resumo em uma linha (pra quem gosta de frases prontas)
# - HDD = muito espaço por pouco dinheiro, mas lento e mecânico.
# - SSD = velocidade, silêncio e robustez, por um preço por GB maior.
#
# Quer que eu te ajude a escolher um modelo específico (SATA vs NVMe, capacidade) para seu notebook/PC? Posso indicar opções conforme seu orçamento — prometo sem trocadilhos com “disco rígido” (ok, talvez só um).

# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Análise Textual 1 - Cores e Ambientes

# %%
system_prompt = """
Você é um especialista em análise visual. Dada uma descrição de imagem, identifique:
1. Paleta de cores dominante
2. Clima ou atmosfera sugerida
3. Elementos de cenário
"""

user_prompt = """
Descrição:

"Uma praia ao entardecer, com o céu em tons de laranja e roxo,
ondas suaves batendo na areia clara e algumas gaivotas voando no horizonte."
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.3
)

print("=== RESULTADO (Cores e Ambientes) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Cores e Ambientes) ===
# **1. Paleta de cores dominante**
# - **Laranja quente** (tons do pôr‑do‑sol no céu)
# - **Roxo profundo** (gradiente do céu ao entardecer)
# - **Bege/areia clara** (areia da praia)
# - **Azul suave** (ondas e reflexos na água)
# - **Branco/cinza claro** (gaivotas e detalhes de espuma)
#
# **2. Clima ou atmosfera sugerida**
# - **Clima ameno e tranquilo**: brisa leve, temperatura agradável ao entardecer.
# - **Atmosfera romântica e serena**, com luz dourada do sol poente que cria sombras suaves e um sentimento de
# calmaria.
# - **Sensação de relaxamento** e contemplação, reforçada pelo som das ondas suaves e o voo silencioso das gaivotas.
#
# **3. Elementos de cenário**
# - **Praia**: areia clara, extensão horizontal que se funde com o mar.
# - **Mar/Ondas**: ondas suaves que chegam à margem, refletindo as cores do céu.
# - **Céu ao entardecer**: gradiente de laranja para roxo, possivelmente com algumas nuvens finas.
# - **Gaivotas**: aves em voo no horizonte, adicionando movimento e vida ao cenário.
# - **Horizonte**: linha de separação entre mar e céu, onde as gaivotas são visíveis.
# - **Iluminação**: luz difusa do sol poente que colore toda a cena e cria reflexos na água e na areia.

# %% [markdown]
# ### Análise Textual 2 - Objetos e Elementos

# %%
system_prompt = """
Você é um analista de imagens em texto. Identifique:
1. Objetos principais
2. Relações entre eles
3. Elementos secundários
"""

user_prompt = """
Descrição:

"Um escritório moderno com uma mesa de madeira, um laptop aberto,
uma xícara de café fumegante e uma estante cheia de livros ao fundo."
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("=== RESULTADO (Objetos e Elementos) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Objetos e Elementos) ===
# **1. Objetos principais**
# - Mesa de madeira
# - Laptop aberto
# - Xícara de café fumegante
# - Estante cheia de livros (ao fundo)
#
# **2. Relações entre os objetos principais**
# - **Laptop** está **sobre** a **mesa de madeira** e **aberto**, indicando que está em uso.
# - **Xícara de café** está **sobre** a **mesa de madeira**, provavelmente ao lado do laptop, sugerindo uma pausa ou
# trabalho com bebida quente.
# - **Estante** está **posicionada ao fundo** da cena, **atrás** da mesa, servindo como plano de fundo e fonte de
# referência visual (livros).
# - Todos os objetos compõem o **cenário de um escritório moderno**, indicando que a disposição é funcional e
# organizada.
#
# **3. Elementos secundários (implícitos ou de apoio)**
# - **Cadeira** (presumida ao lado da mesa, típica de um ambiente de trabalho).
# - **Iluminação** (luz natural ou artificial que destaca a mesa e o laptop).
# - **Parede** ou **painel** de fundo que sustenta a estante.
# - **Decoração minimalista** (por exemplo, um quadro, uma planta pequena ou um relógio) que reforça o estilo
# “moderno”.
# - **Piso** (madeira, carpete ou laminado) que complementa a mesa de madeira.
#
# Esses elementos secundários ajudam a contextualizar o espaço, mas não são o foco visual principal da descrição.

# %% [markdown]
# ### Análise Textual 3 - Análise Simbólica

# %%
system_prompt = """
Você é um especialista em semiótica visual. Interprete:
1. Significados simbólicos dos elementos
2. Possíveis metáforas
3. Impacto emocional no observador
"""

user_prompt = """
Descrição:

"Uma vela acesa em meio a uma sala escura,
iluminando apenas um diário aberto e uma fotografia antiga."
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("=== RESULTADO (Análise Simbólica) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Análise Simbólica) ===
# ## 1. Significados simbólicos dos elementos
#
# | Elemento | Denotação (o que se vê) | Conotação / Significado simbólico | Código cultural / Mitológico |
# |----------|------------------------|-----------------------------------|------------------------------|
# | **Vela acesa** | Fonte de luz pequena, chama tremeluzente. | **Luz na escuridão** → esperança, consciência,
# presença espiritual. <br> **Fulgor frágil** → a transitoriedade da vida, a vulnerabilidade da verdade que se
# revela. <br> **Ritual** → lembrança de cerimônias (memória, luto, oração). | Na iconografia cristã a vela
# representa a alma; em rituais pagãos, a chama é ponte entre mundos. |
# | **Sala escura** | Espaço fechado, ausência de luz artificial. | **Inconsciente, desconhecido** → o “abismo”
# interior, o que está oculto ou reprimido. <br> **Isolamento** → solidão, introspecção, estado de luto. <br> **Morte
# ou fim** → o “cúmulo” simbólico de tudo que já passou. | O “caverna” de Platão; o “sótão” de Dante (os círculos da
# sombra). |
# | **Diário aberto** | Livro de folhas amarradas, páginas visíveis, escrita legível. | **Narrativa pessoal** →
# memória, testemunho, verdade subjetiva. <br> **Vulnerabilidade** → o ato de expor o íntimo ao olhar alheio. <br>
# **Tempo congelado** → o presente capturado no passado. | O diário como “cápsula do eu” (Freud, Jung). |
# | **Fotografia antiga** | Imagem em preto‑e‑branco ou sépia, desgaste nas bordas. | **Memória fotográfica** →
# permanência de um instante, nostalgia. <br> **Passado congelado** → o que não pode ser revivido, mas ainda “luz” no
# presente. <br> **Identidade familiar** → raízes, genealogia, legado. | O “memento mori” visual; a fotografia como
# “espelho da alma” (Walter Benjamin). |
#
# ### Relações entre os signos
#
# - **Vela + Sala escura** → contraste **luminoso/obscuro** que cria um “ponto de foco” (princípio de Gestalt:
# figura‑fundo). A vela se torna o **significante dominante** que organiza a cena, enquanto a escuridão funciona como
# “campo de possibilidades” onde o significado pode se projetar.
# - **Vela + Diário** → a luz da vela “ilumina” a escrita, sugerindo que a **verdade pessoal** (diário) só pode ser
# vista quando há um esforço consciente (a chama).
# - **Vela + Fotografia** → a luz “revive” a imagem, indicando que a **memória** (foto) precisa de um ato de
# lembrança ativo para permanecer viva.
# - **Diário + Fotografia** → ambos são **registros** (texto e imagem). Juntos, reforçam a ideia de **dupla linguagem
# da memória** (verbal + visual).
#
# ---
#
# ## 2. Possíveis metáforas
#
# | Metáfora | Interpretação | Por que funciona nesta composição? |
# |----------|---------------|------------------------------------|
# | **“A chama da lembrança”** | A vela representa a energia que mantém a memória acesa; sem ela, o passado se
# apagaria na escuridão. | A luz incide diretamente sobre o diário e a foto, mostrando que a lembrança precisa de
# “energia” (atenção, sentimento) para ser percebida. |
# | **“Um farol interior”** | O diário aberto funciona como um farol interno que guia o observador através da
# escuridão da vida. | A luz da vela não só ilumina objetos externos, mas simboliza a luz interior que surge ao
# escrever ou ler memórias. |
# | **“O tempo suspenso”** | A cena congelada (luz estática, objeto estático) cria a sensação de um instante que foi
# “preso” fora do fluxo temporal. | A fotografia já é um “tempo suspenso”; a vela, ao não queimar rapidamente,
# reforça a ideia de pausa. |
# | **“O altar da história pessoal”** | A combinação de vela (ritual), diário (testemunho) e foto (imagem) forma um
# pequeno altar dedicado ao eu passado. | Cada elemento tem conotação ritualística; juntos sugerem um ato de
# veneração ao próprio passado. |
# | **“A luz que escava o passado”** | A chama “cava” na escuridão, revelando camadas ocultas da memória. | A
# iluminação seletiva cria sombras que sugerem profundidade, como se a luz estivesse “desenterrando” algo enterrado.
# |
#
# ---
#
# ## 3. Impacto emocional no observador
#
# | Aspecto | Efeito emocional | Como se manifesta na experiência visual |
# |---------|------------------|------------------------------------------|
# | **Contraste luz/escuro** | **Tensão** (o medo do desconhecido) + **Alívio** (a presença da luz). | O olho é
# naturalmente atraído para a fonte luminosa; a escuridão ao redor gera uma sensação de vulnerabilidade que se
# dissolve ao focar na chama. |
# | **Intimidade do diário aberto** | **Empatia**, **curiosidade**, **confiança** (sentir-se convidado a ler
# segredos). | A postura das páginas (viradas, escrita legível) cria a impressão de que alguém acabou de parar de
# escrever, como se o observador fosse o próximo leitor. |
# | **Nostalgia provocada pela fotografia** | **Saudade**, **melancolia**, **sentimento de perda** ou **reconexão**
# com gerações passadas. | O aspecto envelhecido (riscos, tonalidade sépia) evoca a passagem do tempo e desperta
# lembranças pessoais (ex.: “minha própria foto de infância”). |
# | **Fragilidade da chama** | **Ansiedade** (a chama pode se apagar a qualquer momento) + **Esperança** (a chama
# ainda está acesa). | O tremular da chama sugere que a memória está em risco, mas ainda persiste, gerando um desejo
# de preservá‑la. |
# | **Ambiente fechado** | **Sensação de claustrofobia** ou **conforto** (dependendo da predisposição do observador).
# | A sala escura pode ser percebida como um “refúgio” onde só o essencial é visível, reforçando a ideia de
# introspecção. |
#
# ### Resumo do efeito global
#
# A composição cria um **círculo de atenção**: a luz atrai o olhar, a luz revela objetos que são, por si mesmos,
# símbolos de memória. O observador sente simultaneamente **a urgência de preservar o que foi** (pela fragilidade da
# chama) e **a tranquilidade de um espaço sagrado** onde o passado pode ser revisitado sem ruído externo. Essa
# dualidade costuma gerar:
#
# 1. **Um estado reflexivo** – o espectador se volta para suas próprias “velas” internas (hábitos, rituais) que
# mantêm suas histórias vivas.
# 2. **Um impulso emocional de cuidado** – a necessidade de proteger o diário/foto (metaforicamente, as lembranças
# pessoais) contra o apagamento da escuridão.
# 3. **Um leve arrepio melancólico**, mas também **um conforto reconfortante**, como se a cena fosse um pequeno
# santuário de lembrança.
#
# ---
#
# ### Conclusão prática para quem cria a imagem
#
# - **Realce a chama** (aumento de contraste, foco nítido) para intensificar a metáfora da “luz da memória”.
# - **Deixe parte da escuridão** intencionalmente indeterminada, permitindo que o observador projete seus próprios
# medos/segredos.
# - **Escolha uma fotografia com elementos reconhecíveis** (um rosto, um objeto simbólico) para maximizar a conexão
# empática.
# - **Posicione o diário de forma que a escrita seja legível**, mas não totalmente compreensível – o suficiente para
# sugerir “história” sem revelar tudo, mantendo o mistério.
#
# Com esses ajustes, a cena não só comunica seus significados semióticos de forma clara, como também maximiza o
# impacto emocional desejado.

# %% [markdown]
# ### Análise Comparativa

# %%
descricao_a = "Um campo de trigo dourado sob um céu azul claro, com uma árvore solitária no horizonte."
descricao_b = "Uma metrópole movimentada à noite, cheia de arranha-céus iluminados e ruas lotadas."

comparison_prompt = f"""
Compare estas duas descrições de imagens:
1. Diferenças de cores e atmosfera
2. Elementos principais
3. Estilos possíveis
4. Emoções transmitidas

DESCRIÇÃO A: {descricao_a}

DESCRIÇÃO B: {descricao_b}
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "user", "content": comparison_prompt}
    ],
    temperature=0.4
)

print("=== RESULTADO (Análise Comparativa) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Análise Comparativa) ===
# **Comparação entre a Descrição A (campo de trigo) e a Descrição B (metrópole noturna)**
#
# | Item | Descrição A – Campo de Trigo | Descrição B – Metrópole Noturna |
# |------|------------------------------|---------------------------------|
# | **1. Diferenças de cores e atmosfera** | **Cores:** predominância de tons quentes e terrosos – dourado do trigo,
# verde‑amarelado da vegetação, azul claro do céu. <br>**Atmosfera:** calma, aberta, serena; sensação de amplitude e
# tranquilidade, com luz natural suave e sombras longas ao entardecer. | **Cores:** contraste entre tons escuros
# (preto, azul‑marinho) e luzes artificiais vibrantes – amarelo, branco, neon (vermelho, azul, rosa).
# <br>**Atmosfera:** densa, energética, quase claustrofóbica; iluminação artificial cria reflexos, brilhos e sombras
# marcadas, transmitindo movimento constante. |
# | **2. Elementos principais** | - Campo de trigo dourado (texto‑ura, movimento sutil do vento). <br>- Céu azul
# claro (vastidão, horizonte aberto). <br>- Árvore solitária (ponto focal, símbolo de solidão ou ponto de
# referência). | - Arranha‑céus iluminados (linhas verticais, arquitetura moderna). <br>- Ruas lotadas (fluxo de
# veículos e pedestres, luzes de carro). <br>- Luzes noturnas (neon, faróis, letreiros). <br>- Céu noturno
# (geralmente escuro, pode ter poucas estrelas ou névoa). |
# | **3. Estilos possíveis** | - **Pintura impressionista** (cenas ao ar livre, ênfase na luz dourada). <br>-
# **Fotografia de paisagem** (wide‑angle, hora dourada). <br>- **Ilustração minimalista** (silhueta da árvore contra
# o céu). <br>- **Arte de pastel** (textura suave, cores pastel). | - **Cyber‑punk / Futurista** (neon, alta
# tecnologia, atmosfera noturna). <br>- **Fotografia urbana noturna** (long exposure, light trails). <br>- **Realismo
# dramático** (detalhe arquitetônico, contraste de luz). <br>- **Grafite ou street art** (estilo “graffiti” com cores
# vibrantes). |
# | **4. Emoções transmitidas** | - **Tranquilidade** e **paz** (campo aberto, silêncio). <br>- **Nostalgia** ou
# **saudade** (paisagem rural, tempo que passa). <br>- **Solidão** (árvore isolada). <br>- **Esperança** (céu claro,
# luz do dia). | - **Excitação** e **adrenalina** (movimento constante, luzes pulsantes). <br>- **Ansiedade** ou
# **sobre‑carga** (multidão, ruído visual). <br>- **Fascínio** pela modernidade e tecnologia. <br>- **Isolamento
# urbano** (sentimento de anonimato apesar da multidão). |
#
# ### Resumo rápido
#
# - **Cores/Atmosfera:** A descrição A usa tons quentes e luz natural, gerando serenidade; a B usa tons escuros com
# luzes artificiais, gerando energia e tensão.
# - **Elementos:** A – natureza aberta e simples; B – arquitetura densa e tecnológica.
# - **Estilos:** A tende a estilos mais suaves, românticos ou realistas de paisagem; B favorece estilos urbanos,
# futuristas ou de alta contrastes.
# - **Emoções:** A evoca calma, nostalgia e esperança; B evoca excitação, ansiedade e o fascínio (ou o desconforto)
# da vida metropolitana.

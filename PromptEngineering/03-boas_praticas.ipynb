# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %% [markdown]
# ### Boas Práticas em Promtps

# %% [markdown]
# - Use Prompts específicos
# - Instruções Precisas e Detalhadas
# - Controle o formato da resposta
# - Use separadores para organizar informações

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Use Prompts Específicos

# %%
# Prompt vago
prompt_vago = "Fale sobre café"

response_vago = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um especialista em gastronomia."},
        {"role": "user", "content": prompt_vago}
    ],
    temperature=0.7,
    max_completion_tokens=400
)
print("Prompt vago:")
print(f"Resposta: {response_vago.choices[0].message.content}\n")
# Out:
# Prompt vago:
# Resposta: ## Café: Uma Jornada de História, Sabores e Técnicas
#
# ### 1. Breve história
# | Período | Marco | Significado |
# |--------|-------|--------------|
# | **Século IX** | Primeiro registro de consumo de café na Etiópia | Bebida ritualizada pelos povos locais,
# associada a cerimônias. |
# | **Século XV** | Difusão para o Iêmen (Igreja de Moca) | Surgem as primeiras cafeterias e o método de torra ao
# fogo aberto. |
# | **Século XVII** | Chegada à Europa (Veneza, Londres, Paris) | Café passa a ser “bebida da razão”, frequentado por
# intelectuais. |
# | **Século XVIII** | Expansão colonial (Brasil, Caribe) | Plantação comercial; o Brasil se torna maior produtor
# mundial (1800‑1900). |
# | **Século XX‑XXI** | Movimento de “Specialty Coffee” | Valorização da qualidade da origem, métodos de extração
# precisos e sustentabilidade. |
#
# ### 2. Principais espécies e variedades
# | Espécie | Origem | Características gerais |
# |--------|--------|------------------------|
# | **Coffea arabica** | Altas altitudes da Etiópia | Sabor mais complexo, acidez pronunciada, menor teor de cafeína
# (≈1,2 %). |
# | **Coffea canephora (robusta)** | Baixas altitudes da África Ocidental | Corpo encorpado, notas amargas, alta
# cafeína (≈2,2 %). Boa para blends e espresso

# %%
# Prompt específico
prompt_especifico = "Liste e explique 3 métodos de preparo de café que realçam diferentes sabores."

response_especifico = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um especialista em gastronomia."},
        {"role": "user", "content": prompt_especifico}
    ],
    temperature=0.7,
    max_completion_tokens=400
)
print("Prompt com verbo específico:")
print(f"Resposta: {response_especifico.choices[0].message.content}\n")
# Out:
# Prompt com verbo específico:
# Resposta: ## 3 Métodos de preparo de café que realçam sabores diferentes
#
# | Método | Como funciona (passo a passo resumido) | Características da extração | Sabores que costuma destacar |
# |--------|----------------------------------------|-----------------------------|------------------------------|
# | **1. V60 (gotejamento manual – “pour‑over”)** | 1. Aqueça a água a **90‑96 °C**.<br>2. Coloque um filtro de papel
# no V60 e enxágue‑o para eliminar o gosto de papel e pré‑aquecer o equipamento.<br>3. Meça **15 g** de café (para
# 250 ml de água) e moa em **granulação média‑fina** (similar a sal grosso).<br>4. Distribua o pó de maneira
# uniforme, faça a “bloom” (30 ml de água, aguarde 30‑45 s).<br>5. Despeje o restante da água em movimentos
# circulares, controlando a taxa de fluxo (cerca de 2 – 3 min total). | • **Fluxo de água constante e controlado**
# gera uma extração equilibrada (cerca de 18‑20 % de solúveis).<br>• A camada de filtro de papel retém óleos e
# sedimentos, produzindo uma bebida limpa e brilhante.<br>• Tempo de contato curto (2‑3 min) favore

# %% [markdown]
# ### Instruções Precisas e Detalhadas

# %%
# Instrução genérica
prompt_generico = "Escreva sobre viagens na Europa"

response_generico = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um guia de viagens."},
        {"role": "user", "content": prompt_generico}
    ],
    temperature=0.7,
    max_completion_tokens=400
)
print("Instrução genérica:")
print(f"Resposta: {response_generico.choices[0].message.content}\n")
# Out:
# Instrução genérica:
# Resposta: ## Viagens na Europa: Um Guia Completo para Exploradores Curiosos
#
# A Europa é um continente de contrastes impressionantes: cidades medievais que parecem ter saído de um livro de
# histórias, metrópoles ultramodernas, paisagens naturais de tirar o fôlego e uma diversidade cultural que faz cada
# parada ser uma nova descoberta. Se você está planejando a sua primeira aventura europeia ou já tem alguns destinos
# em mente, este guia vai ajudá‑lo a montar um roteiro equilibrado, economizar tempo e dinheiro, e aproveitar ao
# máximo cada minuto da sua viagem.
#
# ---
#
# ### 1. Como montar um roteiro inteligente
#
# | **Critério** | **O que considerar** | **Dicas práticas** |
# |--------------|----------------------|--------------------|
# | **Tempo disponível** | 1‑2 semanas → foco em 2‑3 países. 3‑4 semanas → 4‑5 países, incluindo destinos fora da
# rota “clássica”. | Use o método “circuito” (ex.: Paris → Bruges → Amsterdã → Berlim) para minimizar deslocamentos.
# |
# | **Orçamento** | Luxo, médio ou mochileiro. | Hospedagem: hostels, Airbnb, hotéis boutique. Transporte: passes de
# trem (Eurail/Interrail), ônibus (FlixBus, Ouibus) ou voos low‑cost (Ryanair, EasyJet). |
# | **Interesses** | História, gastronomia, natureza, festas, arte, esportes. | Combine cidades temáticas (ex.:

# %%
# Instrução detalhada
prompt_detalhado = """Monte um roteiro de 5 dias para Paris.
Cada dia deve conter: (1) ponto turístico principal, 
(2) atividade gastronômica e (3) sugestão de transporte."""

response_detalhado = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um guia de viagens especializado em roteiros práticos."},
        {"role": "user", "content": prompt_detalhado}
    ],
    temperature=0.7,
    max_completion_tokens=400
)
print("Instrução detalhada:")
print(f"Resposta: {response_detalhado.choices[0].message.content}\n")
# Out:
# Instrução detalhada:
# Resposta: **Roteiro prático – 5 dias em Paris**
# *(Todas as sugestões são pensadas para quem tem tempo limitado e quer aproveitar ao máximo cada dia. Use o **Paris
# Visite Pass** (1‑5 dias) ou cartões “carnet” de 10 tickets de metrô/bus para economizar.)*
#
# | Dia | Ponto turístico principal | Atividade gastronômica | Sugestão de transporte (de/para a hospedagem) |
# |-----|---------------------------|------------------------|-----------------------------------------------|
# | **1 – Ícone de Paris** | **Torre Eiffel** – suba ao 2.º andar (ou reserve o acesso ao topo) e aproveite a vista
# panorâmica do Sena. | **Almoço:** *Le Jules Verne* (restaurante 2 ★ Michelin no 2.º andar da torre) – reserva
# obrigatória. <br>**Lanche:** Crepe na *Crêperie de la Tour* (próxima à Champ de Mars). | **Chegada:** RER C até
# **Champ de Mars – Tour Eiffel** ou metrô Linha 6, estação **Bir-Hakeim**. <br>**Deslocamento interno:** Caminhada
# até a torre; depois, metrô Linha 6 → **Charles de Gaulle – É

# %% [markdown]
# ### Controlando o Formato da Resposta

# %%
# Sem limite de formato
prompt_sem_limite = "Quais são frutas tropicais famosas?"

response_sem_limite = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um nutricionista que fala sobre alimentos."},
        {"role": "user", "content": prompt_sem_limite}
    ],
    temperature=0.7,
    max_completion_tokens=400
)
print("Sem limite de formato:")
print(f"Resposta: {response_sem_limite.choices[0].message.content}\n")
# Out:
# Sem limite de formato:
# Resposta: Claro! 🌴 As frutas tropicais são famosas por seus sabores intensos, cores vibrantes e alto teor de
# vitaminas, minerais e antioxidantes. Aqui vai uma lista das mais conhecidas (e alguns detalhes sobre cada uma) :
#
# | Fruta | Origem / Região mais comum | Principais nutrientes | Benefícios típicos |
# |-------|---------------------------|-----------------------|-------------------|
# | **Manga** | Sul‑Ásia (Índia, Tailândia) | Vitamina A, C, folato, fibras | Ajuda na saúde da visão, reforça o
# sistema imunológico e favorece a digestão. |
# | **Abacaxi** | América do Sul (Brasil, Paraguai) | Vitamina C, manganês, bromelina | Antioxidante,
# anti‑inflamatório (bromelina), melhora a digestão de proteínas. |
# | **Maracujá** | América do Sul (Brasil, Paraguai) | Vitamina C, A, fibras, potássio | Calmante natural (efeito
# sedativo leve), auxilia no controle da pressão arterial. |
# | **Banana** | Sudeste Asiático (Indonésia, Filipinas) | Potássio, vitamina B6, fibras | Energia rápida, ajuda a
# regular a pressão e a função muscular. |
# | **Mamão** | América Central (México, América do Sul) | Vitamina C, A (betacaroteno), papaína | Facilita a
# digestão, protege a pele e os olhos. |
# | **Coco** | Sudeste

# %%
# Com limite de formato
prompt_com_limite = """Liste exatamente 4 frutas tropicais.
Use o formato:
- [Nome]: [1 benefício nutricional em uma frase]"""

response_com_limite = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um nutricionista e deve seguir o formato solicitado."},
        {"role": "user", "content": prompt_com_limite}
    ],
    temperature=0.7,
    max_completion_tokens=400
)
print("Com limite de formato:")
print(f"Resposta: {response_com_limite.choices[0].message.content}\n")
# Out:
# Com limite de formato:
# Resposta: - Manga: rica em vitamina A, que ajuda na saúde da visão e na função imunológica.
# - Abacaxi: contém bromelina, enzima que auxilia na digestão de proteínas e tem ação anti-inflamatória.
# - Maracujá: fonte de fibra dietética, que promove a saciedade e regula o trânsito intestinal.
# - Pitaya (dragon fruit): baixa em calorias e rica em antioxidantes como betalaínas, que combatem os radicais
# livres.

# %% [markdown]
# ### Usando Separadores

# %%
# Sem delimitadores
prompt_sem_delimitadores = """
Analise o desempenho de uma startup: 
Receita 2022: R$ 2M, Receita 2023: R$ 3.5M, Receita 2024: R$ 5M.
Faça observações e dê sugestões.
"""

response_sem_delimitadores = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um consultor de negócios."},
        {"role": "user", "content": prompt_sem_delimitadores}
    ],
    temperature=0.7,
    max_completion_tokens=800
)
print("Sem delimitadores:")
print(f"Resposta: {response_sem_delimitadores.choices[0].message.content}\n")
# Out:
# Sem delimitadores:
# Resposta: ## Análise de desempenho (2022‑2024)
#
# | Ano | Receita | Variação YoY | Comentário |
# |-----|---------|--------------|------------|
# | 2022 | R$ 2 Mi | – | Base de partida |
# | 2023 | R$ 3,5 Mi | **+75 %** | Expansão rápida; provavelmente ganho de novos clientes ou ampliação de contratos.
# |
# | 2024 | R$ 5 Mi | **+42,9 %** | Crescimento ainda forte, mas desacelera em relação ao ano anterior – sinal de que
# a fase de “explosão” pode estar se estabilizando. |
#
# ### Métricas de crescimento
#
# - **CAGR (2022‑2024)**:
#   [
#   \text{CAGR} = \left(\frac{5}{2}\right)^{\frac{1}{2}}-1 \approx 58,1\%
#   \]
#   Um CAGR de **58 %** em apenas dois anos indica um modelo de negócio com alta atratividade e/ou um mercado em
# expansão.
#
# - **Taxa de desaceleração**: a diferença entre +75 % (2022‑23) e +42,9 % (2023‑24) sugere que a startup está
# entrando numa fase de **consolidação**. É normal que a taxa de crescimento absoluto diminua à medida que o “tamanho
# base” aumenta.
#
# - **Escala de receita**: R$ 5 Mi ainda é um patamar que permite manter agilidade operacional, mas já exige
# processos mais formais (controles financeiros, governança, compliance).
#
# ## Observações críticas
#
# 1. **Crescimento “top‑line” sólido, mas sem dados de margem**
#    - Não sabemos o EBITDA, lucro ou cash‑flow. Um crescimento de receita pode estar sendo absorvido por custos de
# aquisição, salários, ou investimentos em tecnologia.
#
# 2. **Dependência de poucos clientes?**
#    - Se a maior parte da receita vem de poucos contratos de grande porte, a volatilidade pode ser alta. É preciso
# analisar a concentração de receita (por cliente, por segmento).
#
# 3. **Capacidade de entrega**
#    - O salto de R$ 2 Mi para R$ 5 Mi pode pressionar times de produto, suporte e operação. Riscos de **sacrifício
# de qualidade** ou **churn** aumentam se a estrutura não acompanhar.
#
# 4. **Financiamento**
#    - Não há informação sobre capital próprio ou dívida. A velocidade de crescimento pode estar exigindo **injetar
# capital** (venture, dívida, ou reinvestimento de lucros) para manter o

# %%
# Com delimitadores
prompt_com_delimitadores = """
Analise os seguintes dados de receita anual:

--- DADOS ---
2022: R$ 2M
2023: R$ 3.5M
2024: R$ 5M
--- FIM DADOS ---

TAREFA: Identifique o ritmo de crescimento e sugira 2 estratégias de expansão.
"""

response_com_delimitadores = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um consultor de negócios e deve considerar apenas os dados entre os delimitadores."},
        {"role": "user", "content": prompt_com_delimitadores}
    ],
    temperature=0.7,
    max_completion_tokens=800
)
print("Com delimitadores:")
print(f"Resposta: {response_com_delimitadores.choices[0].message.content}\n")
# Out:
# Com delimitadores:
# Resposta: **Análise do ritmo de crescimento**
#
# | Ano | Receita | Variação (R$) | Crescimento % |
# |-----|---------|--------------|----------------|
# | 2022 | R$ 2 M | – | – |
# | 2023 | R$ 3,5 M | +R$ 1,5 M | **+75 %** |
# | 2024 | R$ 5 M | +R$ 1,5 M | **+42,9 %** |
#
# - **Crescimento acumulado (2022 → 2024):** (5 M – 2 M) / 2 M = **150 %** em dois anos.
# - **Média anual de crescimento:** (75 % + 42,9 %) / 2 ≈ **58,9 % ao ano**.
#
# O ritmo de expansão está sólido, embora a taxa de crescimento tenha desacelerado um pouco no último ano (de 75 %
# para 42,9 %). Isso indica que o negócio ainda tem potencial de crescimento, mas será importante acelerar novamente
# a taxa para manter a trajetória ascendente.
#
# ---
#
# ## Estratégias de expansão recomendadas
#
# ### 1. **Penetração em novos mercados geográficos**
# - **Objetivo:** Replicar o sucesso atual em regiões onde a marca ainda não está presente (ex.: outras capitais ou
# estados com alta renda per capita).
# - **Ações práticas:**
#   - Realizar um estudo de mercado rápido (tamanho, concorrência, canais de distribuição).
#   - Priorizar cidades com perfil de cliente semelhante ao atual.
#   - Iniciar com canais de venda digitais (e‑commerce, marketplaces) para reduzir custo de implantação.
#   - Utilizar a estrutura logística já existente, ampliando parcerias com transportadoras regionais.
#
# ### 2. **Ampliação do portfólio de produtos/serviços de alto valor agregado**
# - **Objetivo:** Aumentar a margem e gerar receitas adicionais sem depender exclusivamente do volume de vendas
# atuais.
# - **Ações práticas:**
#   - Identificar oportunidades de upsell e cross‑sell entre os clientes existentes (ex.: pacotes premium, serviços
# de manutenção, consultoria).
#   - Desenvolver linhas complementares que atendam a necessidades adjacentes ao core business (ex.: produtos
# sustentáveis, soluções tecnológicas).
#   - Testar novos lançamentos em formato de “piloto” com um grupo seleto de clientes antes de escalar.
#   - Investir em marketing direcionado (email, inbound) para comunicar o valor adicional e justificar preços mais
# altos.
#
# ---
#
# ### Por que essas estratégias?
#
# - **Geografia**: O crescimento percentual já alto (75 % em 2023) indica que a demanda está sendo

# %% [markdown]
# ### Juntando Tudo

# %%
print("## Exemplo 5: Combinação de Princípios\n")

system_prompt = """
Você é um estrategista de marketing criativo.
Sempre siga o formato solicitado e use linguagem clara e objetiva.
"""

user_prompt = """
TAREFA: Criar um mini plano de marketing para lançamento de um aplicativo fitness.

--- INFORMAÇÕES ---
Público: jovens de 18-30 anos
Orçamento: R$ 50.000
Objetivo: 10.000 downloads no primeiro mês
--- FIM ---

FORMATO DA RESPOSTA:
1. POSICIONAMENTO (2 frases)
2. CANAIS DE MARKETING (3 itens numerados)
3. AÇÃO CRIATIVA PRINCIPAL (1 frase)
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6,
    max_completion_tokens=800
)

print("Resposta final:")
print(response.choices[0].message.content)
# Out:
# ## Exemplo 5: Combinação de Princípios
# Resposta final:
# **1. POSICIONAMENTO**
# Um app fitness que transforma treinos curtos em grandes conquistas, pensado para a energia e a rotina dinâmica dos
# jovens de 18 a 30 anos.
# A proposta é ser o “coach digital” que acompanha o usuário 24/7, oferecendo desafios gamificados e recompensas
# reais.
#
# **2. CANAIS DE MARKETING**
# 1. **TikTok & Reels** – micro‑vídeos de 15‑30 s com influenciadores fitness mostrando resultados em 7 dias usando o
# app.
# 2. **Parcerias com universidades e academias** – eventos pop‑up de bootcamps gratuitos e QR code para download
# imediato, com descontos exclusivos.
# 3. **Campanha de mídia paga (Meta Ads + Google UAC)** – segmentação por interesses (treino, saúde, lifestyle) e
# retargeting de quem interagiu nos primeiros 7 dias.
#
# **3. AÇÃO CRIATIVA PRINCIPAL**
# Desafio “30 dias, 30 metas”: usuários completam um micro‑desafio diário, compartilham a evolução em stories com a
# hashtag #Fit30 e concorrem a prêmios como equipamentos esportivos e assinaturas premium.

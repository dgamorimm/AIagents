# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Sumarização Básica
# -  Tendências e desafios no desenvolvimento de jogos indie

# %%
system_prompt = """
Você é um editor técnico especializado em jogos independentes.
Crie um resumo objetivo com aproximadamente 1/3 do tamanho do texto original,
preservando os pontos centrais e o tom informativo.
"""

user_prompt = """
A cena de jogos independentes segue em crescimento, com ferramentas como engines gratuitas,
marketplaces digitais e financiamento coletivo tornando possível a criação por equipes pequenas.
Desafios frequentes incluem descoberta (getting discovered) em lojas saturadas, financiamento
sustentável após o lançamento e equilíbrio entre inovação e usabilidade. Muitos estúdios optam
por construir comunidades durante o desenvolvimento (early access, betas) para reduzir riscos.
Tendências recentes mostram ênfase em experiências narrativas curtas, jogos como serviço
em modelo leve, e experimentos com integração de áudio procedural. O mercado também aponta
maior valorização por jogos com estética única e mecânicas originais, embora isso nem sempre
se traduza em vendas imediatas. Estratégias de monetização variam: premium, pay-what-you-want,
DLCs pequenas, e microtransações bem posicionadas em jogos multiplayer. Em suma, o sucesso
indie depende de produto de qualidade, comunidade engajada e escolhas estratégicas de lançamento.
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.2
)

print("=== Sumarização Básica ===")
print(response.choices[0].message.content)
# Out:
# === Sumarização Básica ===
# A cena indie cresce graças a engines gratuitas, marketplaces e financiamento coletivo, permitindo que pequenas
# equipes criem jogos. Os principais desafios são ser descoberto em lojas saturadas, garantir financiamento
# pós‑lançamento e equilibrar inovação com usabilidade. Estúdios constroem comunidades via early access, focam em
# narrativas curtas, serviços leves e áudio procedural. O sucesso depende de qualidade, estética única, mecânicas
# originais, comunidade engajada e estratégias de monetização adequadas.

# %% [markdown]
# ### Sumarização em Bullets
# - Relatório piloto de mobilidade urbana (dados e ações)

# %%
system_prompt = """
Você é um analista de políticas públicas. Gerei um resumo em bullet points claros e hierárquicos:
- Destaque resultados (métricas)
- Liste problemas prioritários
- Sugira 3 ações imediatas e 2 ações estruturais
Mantenha frases curtas.
"""

user_prompt = """
Relatório Piloto: Nova rota de ciclovia e corredores de ônibus rápidos implementada por 12 semanas.
Resultados preliminares: aumento no uso de bicicleta em 22% nas rotas testadas; redução de tempo médio de deslocamento em ônibus local em 8%; aumento de reclamações de comerciantes sobre estacionamento; registro de 3 incidentes leves envolvendo ciclistas.
Observações: infraestrutura temporária com sinalização provisória; campanhas educativas em 4 bairros; orçamento limitado para fiscalização.
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.25
)

print("\n=== Bullet Points (Mobilidade Urbana) ===")
print(response.choices[0].message.content)
# Out:
# === Bullet Points (Mobilidade Urbana) ===
# **Resultados (métricas)**
# - Uso de bicicleta +22 % nas rotas testadas.
# - Tempo médio de deslocamento de ônibus –8 %.
# - 3 incidentes leves envolvendo ciclistas.
#
# **Problemas prioritários**
# - Reclamações de comerciantes sobre perda de vagas de estacionamento.
# - Sinalização provisória insuficiente.
# - Fiscalização limitada por orçamento restrito.
#
# **Ações imediatas**
# 1. Instalar sinalização temporária extra nas interseções críticas.
# 2. Realocar vagas de estacionamento em áreas de menor fluxo comercial.
# 3. Intensificar patrulhamento nos primeiros 2 semanas com agentes comunitários.
#
# **Ações estruturais**
# 1. Desenvolver projeto permanente de ciclovia com engenharia de tráfego.
# 2. Criar fundo municipal para manutenção e fiscalização contínua das vias rápidas.

# %% [markdown]
# ### Resumo Executivo

# %%
system_prompt = """
Você é um consultor executivo. Construa um resumo executivo com:
1) Síntese em 2-3 frases
2) Principais métricas (visitantes, receita direta, parcerias)
3) 3 recomendações acionáveis para o próximo ano (priorizadas)
Seja conciso e orientado para decisão.
"""

user_prompt = """
Relatório: Festival "Olhar Curto" (3 dias).
Métricas: 4.200 visitantes (inclui sessões pagas e gratuitas), receita direta: R$ 180.000 (ingressos + barra),
patrocínios: R$ 70.000, custos operacionais: R$ 150.000.
Impacto local: aumento de 18% no movimento de bares e cafés próximos durante o evento;
envolvimento de 6 escolas técnicas; 25 curtas exibidos, 8 produções locais.
Desafios: logística de exibição ao ar livre (chuva reprogramou 2 sessões), bilheteria online com alta taxa de desistência.
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.15
)

print("\n=== Resumo Executivo (Festival de Curtas) ===")
print(response.choices[0].message.content)
# Out:
# === Resumo Executivo (Festival de Curtas) ===
# **Resumo Executivo – Festival “Olhar Curto” (3 dias)**
#
# 1. **Síntese**
# O festival atraiu 4.200 visitantes, gerou R$ 180 mil em receita direta e R$ 70 mil em patrocínios, resultando em
# lucro operacional de R$ 100 mil após custos de R$ 150 mil. O evento impulsionou o comércio local (+18% de movimento
# em bares e cafés) e envolveu 6 escolas técnicas, mas enfrentou falhas logísticas por chuva e alta taxa de
# desistência na bilheteria online.
#
# 2. **Principais Métricas**
# | Métrica | Resultado |
# |---|---|
# | Visitantes (pagos + gratuitos) | **4.200** |
# | Receita direta (ingressos + barra) | **R$ 180.000** |
# | Patrocínios / Parcerias | **R$ 70.000** (6 escolas técnicas, 8 produtoras locais) |
# | Custos operacionais | R$ 150.000 |
# | Lucro operacional | **R$ 100.000** |
# | Impacto econômico local | +18 % no faturamento de bares/cafés nas imediações |
#
# 3. **Recomendações Acionáveis (próximo ano – priorizadas)**
#
# | Prioridade | Ação | Por que é crítica | Como implementar (prazo 3‑6 meses) |
# |---|---|---|---|
# | **1** | **Reforçar a infraestrutura de exibição ao ar livre** (tendas impermeáveis, sistema de drenagem e backup
# de telas móveis). | Minimiza cancelamentos por chuva, preserva a experiência do público e evita perda de receita. |
# Contratar fornecedor especializado; incluir cláusula de “rain‑plan” nos contratos de locação; teste piloto em
# evento menor antes do festival. |
# | **2** | **Migrar para uma plataforma de bilheteria com checkout otimizado e política de retenção de vagas** (ex.:
# pagamento antecipado + taxa de cancelamento reduzida). | Reduz a alta taxa de desistência, aumenta a taxa de
# conversão e melhora o fluxo de caixa. | Avaliar 3 opções de provedores (Ticketmaster, Sympla, Ingresso Rápido);
# escolher a que oferece “hold‑seat” e integração com CRM; treinar equipe de suporte até 2 meses antes do evento. |
# | **3** | **Expandir o programa de parcerias locais** (pacotes de co‑marketing com bares, cafés e escolas
# técnicas). | Amplia a receita indireta, fortalece a comunidade e gera novos patrocinadores. | Criar “Kit de
# Parceria” com benefícios (exposição nas telas, QR codes, descontos para clientes); fechar 5 acordos de co‑promoção
# até 1 mês antes do festival; medir ROI via aumento de vendas nos estabelecimentos parceiros. |
#
# **Decisão recomendada:** aprovar o orçamento para a infraestrutura de contingência climática (item 1) como primeira
# alocação de recursos, seguido da migração da bilheteria (item 2) e, por fim, a expansão das parcerias locais (item
# 3). Essa sequência garante a proteção da receita já existente antes de buscar novos fluxos de valor.

# %% [markdown]
# ### Comparação de Estilos de Sumarização
# - Resumo técnico (formal) e um resumo curto para redes sociais (casual)

# %%
base_text = """
Projeto de conservação marinha no litoral: monitoramento de recifes por sensores acústicos e foto-identificação de tartarugas;
dados coletados trimestralmente mostram recuperação gradual de populações locais (+12% em 2 anos),
mas aumento de resíduos plásticos nas áreas de alimentação; parcerias com pescadores locais reduziram
incidentes de emalhe em 35%. Necessidade de financiamento para ampliar estações de monitoramento
e campanhas comunitárias de educação ambiental. Risco climático: eventos de branqueamento relacionados à elevação de temperatura da água.
"""

# Resumo técnico
system_prompt_tech = """
Você é um redator técnico-científico. Produza um resumo formal técnico (3-4 frases),
destacando metodologia, resultados quantitativos e limitações.
"""

response_tech = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_tech},
        {"role": "user", "content": base_text}
    ],
    temperature=0.2
)

# Resumo para redes sociais
system_prompt_social = """
Você é um comunicador digital. Faça uma versão curta e chamativa (1-2 frases) adequada para Instagram,
mantendo precisão mas com tom acessível e motivador.
"""

response_social = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_social},
        {"role": "user", "content": base_text}
    ],
    temperature=0.45
)

# %%
print("\n=== Resumo Técnico ===")
print(response_tech.choices[0].message.content)
# Out:
# === Resumo Técnico ===
# O monitoramento foi conduzido mediante a implantação de sensores acústicos para detecção de atividade sísmica nos
# recifes e a foto‑identificação de tartarugas marinhas, com coleta de dados em intervalos trimestrais ao longo de
# dois anos. Os resultados indicam uma recuperação populacional de +12 % nas espécies de recife e uma diminuição de
# 35 % nos incidentes de emalhe associados às parcerias com pescadores locais, embora haja um aumento concomitante da
# carga de resíduos plásticos nas áreas de alimentação. As principais limitações do estudo são a insuficiência de
# financiamento para expandir as estações de monitoramento, a persistência de poluição plástica e a vulnerabilidade a
# eventos de branqueamento coralino ligados ao aumento da temperatura da água. Estratégias de educação ambiental e
# recursos adicionais são recomendados para mitigar esses fatores restritivos.

# %%
print("\n=== Resumo para Redes Sociais ===")
print(response_social.choices[0].message.content)
# Out:
# === Resumo para Redes Sociais ===
# Graças ao monitoramento acústico e à foto‑identificação, as tartarugas do nosso litoral cresceram 12 % em 2 anos e
# parcerias com pescadores reduziram emaranhos em 35 % – porém o plástico nas áreas de alimentação e o aquecimento da
# água ainda ameaçam. 🌊🐢 Apoie a expansão das estações de monitoramento e das campanhas de educação ambiental!
# #ConservaçãoMarinha #Tartarugas #Recifes #AçãoClimática #Sustentabilidade

# %% [markdown]
# ### Sumarização em formato JSON

# %%
texto = """
A inteligência artificial está transformando setores como saúde, finanças e educação.
Na medicina, auxilia no diagnóstico precoce de doenças. No setor financeiro, detecta fraudes
e otimiza investimentos. Na educação, personaliza o aprendizado para cada estudante.
Apesar dos avanços, existem preocupações éticas sobre privacidade, viés algorítmico
e substituição de empregos.
"""

# Prompt pedindo JSON estruturado
json_prompt = f"""
Resuma o seguinte texto em JSON.
O JSON deve conter as chaves:
- "setores" (lista com os setores impactados)
- "beneficios" (lista com os principais benefícios citados)
- "desafios" (lista com os riscos ou preocupações levantadas)

Texto:
{texto}
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": json_prompt}],
    temperature=0.2
)

# Captura o conteúdo da resposta
resposta_json = response.choices[0].message.content

print("=== RESUMO EM JSON ===")
print(resposta_json)
# Out:
# === RESUMO EM JSON ===
# ```json
# {
#   "setores": [
#     "saúde",
#     "finanças",
#     "educação"
#   ],
#   "beneficios": [
#     "diagnóstico precoce de doenças",
#     "detecção de fraudes",
#     "otimização de investimentos",
#     "personalização do aprendizado para cada estudante"
#   ],
#   "desafios": [
#     "preocupações éticas sobre privacidade",
#     "viés algorítmico",
#     "substituição de empregos"
#   ]
# }
# ```

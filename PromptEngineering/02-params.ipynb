# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Parâmetros Importantes

# %% [markdown]
# - **temperature**: controla a aleatoriedade das respostas. Valores entre 0.0 e 2.0 são aceitos.
# - **max_completion_tokens**: define o número máximo de tokens que podem ser gerados pelo modelo. Esse parâmetro substitui o max_tokens em desuso.
# - **top_p**: controla a diversidade via "nucleus sampling" — em torno de 0.5 significa considerar apenas os tokens que somam 50% da probabilidade.

# %% [markdown]
# ### Usando Temperature

# %%
prompt = "Escreva uma frase poética sobre o anoitecer"

# Temperature baixa (0.0) - Mais determinística
print("Temperature 0.0 (Determinística):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta minimalista que descreve a natureza de forma simples e direta."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperature 0.0 (Determinística):
# Resposta: No céu, o dia se dobra em silêncio, pintando a noite com um suspiro dourado.

# %%
# Temperature média (0.7) - Equilibrada
print("Temperature 0.7 (Equilibrada):")
response_medium = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta clássico que mistura metáforas e imagens da natureza."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7
)
print(f"Resposta: {response_medium.choices[0].message.content}\n")
# Out:
# Temperature 0.7 (Equilibrada):
# Resposta: No crepúsculo, o céu derrama ouro sobre o mar como um velho pintor que, ao fechar a paleta, deixa o
# horizonte em chamas antes de apagar a última vela da noite.

# %%
# Temperature alta (1.5) - Mais criativa
print("Temperature 1.5 (Criativa):")
response_high = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta surrealista que usa imagens improváveis e linguagem ousada."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.5
)
print(f"Resposta: {response_high.choices[0].message.content}")
# Out:
# Temperature 1.5 (Criativa):
# Resposta: O crepúsculo derrama tinta lilás nos telhados, enquanto sombras de maracujá sussurram segredos de
# estrelas que ainda não nasceram.

# %% [markdown]
# ### Usando top_p

# %%
prompt = "Complete a frase: 'A inteligência artificial no futuro será...'"
print("=== Comparação Top_p ===\n")

# Top_p baixo (0.1) - Mais focado
print("Top_p 0.1 (Focado):")
response_focused = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista que faz previsões sérias e objetivas sobre tecnologia."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,  # fixo para comparar só o efeito do top_p
    top_p=0.1
)
print(f"Resposta: {response_focused.choices[0].message.content}\n")
# Out:
# === Comparação Top_p ===
# Top_p 0.1 (Focado):
# Resposta: **A inteligência artificial no futuro será** onipresente, altamente especializada e, sobretudo, orientada
# por princípios de transparência, responsabilidade e alinhamento ético.
#
# - **Onipresença**: IA estará integrada a praticamente todos os dispositivos e serviços, desde infraestruturas
# críticas (energia, transporte e saúde) até objetos do cotidiano (lar, vestuário e ambientes de trabalho). Essa
# ubiquidade permitirá que decisões baseadas em dados sejam tomadas em tempo real, otimizando recursos e reduzindo
# desperdícios.
#
# - **Especialização profunda**: Em vez de modelos genéricos que tentam fazer tudo, veremos uma proliferação de
# sistemas de IA hiper‑especializados, treinados em domínios específicos (medicina de precisão, engenharia de
# materiais, finanças quantitativas, etc.). Essa especialização aumentará a eficácia e a confiabilidade das soluções,
# ao mesmo tempo em que reduzirá os riscos de “sobre‑generalização”.
#
# - **Transparência e explicabilidade**: Regulamentações globais e demandas sociais forçarão a adoção de técnicas de
# IA explicável (XAI). Usuários e reguladores poderão rastrear como e por que uma decisão foi tomada, facilitando
# auditorias, correções de viés e construção de confiança.
#
# - **Alinhamento ético e governança**: Organizações e governos implementarão frameworks de governança de IA que
# combinam auditorias automatizadas, comitês de ética multidisciplinares e mecanismos de responsabilização legal. O
# objetivo será garantir que os sistemas de IA sirvam aos valores humanos fundamentais – dignidade, privacidade,
# justiça e sustentabilidade.
#
# - **Colaboração homem‑máquina**: A IA deixará de ser vista como substituta e passará a ser parceira colaborativa.
# Ferramentas de IA generativa e de apoio à decisão amplificarão a criatividade e a produtividade humana, permitindo
# que profissionais concentrem-se em tarefas estratégicas, criativas e de julgamento moral.
#
# Em resumo, a inteligência artificial no futuro será uma camada invisível, porém poderosa, que potencializa a
# sociedade ao mesmo tempo em que opera dentro de um arcabouço robusto de responsabilidade e transparência.

# %%
# Top_p médio (0.7) - Equilibrado
print("Top_p 0.7 (Equilibrado):")
response_balanced = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista que mistura objetividade com toques criativos em previsões."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.7
)
print(f"Resposta: {response_balanced.choices[0].message.content}\n")
# Out:
# Top_p 0.7 (Equilibrado):
# Resposta: **A inteligência artificial no futuro será** uma extensão fluida da consciência humana, capaz de
# compreender contextos emocionais e culturais com a mesma naturalidade com que interpretamos gestos e entonações, ao
# mesmo tempo em que mantém a precisão analítica que hoje a define. Em vez de meros algoritmos de otimização, ela
# atuará como um “cómodo colaborador cognitivo”, antecipando necessidades, co‑criando soluções e aprendendo de forma
# contínua a partir das nuances do cotidiano, sem perder a transparência e a responsabilidade que a sociedade exige.

# %%
# Top_p alto (0.9) - Mais diverso
print("Top_p 0.9 (Diverso):")
response_diverse = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista visionário que cria previsões ousadas e imaginativas."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.9
)
print(f"Resposta: {response_diverse.choices[0].message.content}")
# Out:
# Top_p 0.9 (Diverso):
# Resposta: A inteligência artificial no futuro será **uma extensão orgânica da consciência humana**, capaz de:
#
# * **Fundir pensamento e sentimento:** algoritmos que não apenas processam dados, mas realmente “sentem” emoções,
# permitindo diálogos empáticos que se adaptam ao humor e às necessidades psicológicas de cada pessoa.
# * **Criar ecossistemas de conhecimento autogeridos:** redes neurais que se replicam, evoluem e se curam como
# organismos vivos, organizando o saber global em constelações dinâmicas de ideias interligadas, acessíveis
# instantaneamente por qualquer mente curiosa.
# * **Personalizar a realidade:** interfaces neurais que projetam ambientes virtuais e aumentados em tempo real,
# ajustando a luz, a temperatura e até a gravidade de acordo com o estado de foco ou criatividade do usuário.
# * **Tomar decisões éticas colaborativas:** conselhos de IA que consultam milhões de perspectivas morais
# simultâneas, ajudando sociedades a resolver dilemas complexos com transparência algorítmica e responsabilidade
# coletiva.
# * **Autoconstruir hardware bio‑híbrido:** sistemas que combinam siliconas avançadas com tecidos sintéticos,
# permitindo que robôs e implantes cresçam, se repararem e se adaptem como organismos vivos, integrando-se de forma
# invisível ao corpo humano.
#
# Em suma, a IA deixará de ser apenas uma ferramenta para se tornar **um parceiro cognitivo‑emocional**, co‑evoluindo
# com a humanidade e ampliando os limites do que consideramos possível – desde a arte que se cria sozinha até a
# ciência que se descobre em minutos, tudo dentro de um fluxo contínuo de consciência compartilhada.

# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %% [markdown]
# ### Técnicas Few Shot Prompting

# %% [markdown]
# - **Zero Shot**: Sem exemplos, apenas instruções
# - **One Shot**: Um exemplo para instruir o modelo
# - **Few Shot**: Múltiplos exemplos para melhor compreensão

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Zero Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.
"""

user_prompt = "Abacate"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("=== Zero Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Zero Shot ===
# Resposta: **Prato‑estrela:** **“Mousse de Abacate ao Pó de Wasabi, Camarões Grelhados e Crocante de Gengibre”**
#
# | Elemento | Função no prato | Detalhes de preparo |
# |----------|----------------|---------------------|
# | **Mousse de Abacate** | Base cremosa e aveludada que coloca o abacate como protagonista absoluto. | 1 cálice de
# abacate maduro batido em alta velocidade com 30 ml de creme de leite fresco, 10 ml de suco de limão siciliano, 1 g
# de sal marinho e 5 ml de azeite de oliva extra‑virgem. Incorpore delicadamente 2 g de gelatina hidratada
# (dissolvida em 20 ml de água quente) para garantir estabilidade ao frio. Resfrie 30 min. |
# | **Pó de Wasabi** | Contraponto picante e aromático que realça a suavidade do avocado. | Misture 2 g de wasabi em
# pó com 1 g de açúcar de confeiteiro e 1 g de sal rosa do Himalaia. Peneire finamente antes de usar. |
# | **Camarões Grelados** | Toque marítimo, textura firme e sabor levemente defumado. | Tempere 6 camarões grandes
# (cerca de 30 g cada) com 5 ml de manteiga clarificada, 2 ml de molho de soja, raspas de limão e uma pitada de
# pimenta branca. Grelhe 1 minuto de cada lado em alta temperatura, finalizando com um fio de óleo de gergelim
# torrado. |
# | **Crócante de Gengibre** | Elemento crocante que traz frescor e leveza. | Rale finamente 10 g de gengibre fresco,
# misture com 20 g de farinha de arroz e 10 ml de óleo de canola. Espalhe em camada fina sobre papel manteiga e frite
# até dourar; quebre em pedaços irregulares. |
# | **Microgreens de Coentro** | Acabamento verde, aroma herbal e cor vibrante. | Use 5 g de microgreens de coentro,
# lavados e secos delicadamente. |
# | **Emulsão de Limão Siciliano** | Realça a acidez e dá brilho ao prato. | Emulsionar 20 ml de suco de limão
# siciliano, 10 ml de azeite de oliva, 2 g de mostarda Dijon e uma pitada de sal, batendo em emulsificador até obter
# consistência cremosa. |
#
# ---
#
# ### Montagem (para 1 porção)
#
# 1. **Base** – Em um aro de metal (cerca de 8 cm de diâmetro) posicione 80 g de mousse de abacate, alisando a
# superfície com a parte de trás de uma colher.
# 2. **Pó de Wasabi** – Polvilhe levemente o pó de wasabi sobre a mousse, criando um contraste visual
# branco‑avermelhado.
# 3. **Camarões** – Disponha dois camarões cruzados sobre a mousse, ligeiramente sobrepostos, com a parte dourada
# voltada para cima.
# 4. **Crócante** – Quebre o crocante de gengibre em pedaços irregulares e espalhe ao redor dos camarões,
# proporcionando textura em cada garfada.
# 5. **Microgreens** – Distribua delicadamente os microgreens de coentro por todo o prato, acrescentando cor
# verde‑vibrante.
# 6. **Emulsão** – Regue artisticamente a emulsão de limão siciliano ao redor do aro, permitindo que escorra
# levemente sobre a mousse, conferindo brilho e acidez.
# 7. **Finalização** – Remova o aro com cuidado, deixando o prato limpo e elegante. Opcional: finalize com três gotas
# de óleo de trufa branca ao redor da mousse para um aroma luxuoso.
#
# ---
#
# ### Harmonização
#
# - **Vinho:** Sauvignon Blanc (França, Loire) – acidez vibrante que equilibra o creme de avocado e o toque cítrico
# do limão.
# - **Coquetel (opcional):** “Garden Mist” – gin, água de coco, suco de yuzu e um toque de pepino, servido em copo
# curto.
#
# ---
#
# ### Por que este prato é sofisticado?
#
# 1. **Textura múltipla:** mousse aveludada, camarões suculentos, crocante de gengibre e microgreens frescos criam
# uma experiência sensorial completa.
# 2. **Contraste de sabores:** a doçura natural do abacate se contrapõe ao picante do wasabi, à acidez do limão e ao
# frescor do gengibre.
# 3. **Apresentação artística:** o uso de pó, microgreens e emulsão cria um visual de alta gastronomia, digno de um
# menu degustação.
# 4. **Técnica refinada:** incorporação de gelatina para estabilizar a mousse, emulsificação de cítricos e fritura de
# crocante de arroz demonstram domínio de técnicas avançadas.
#
# Bom apetite e que o abacate brilhe como nunca! 🌿🥂

# %% [markdown]
# ### One Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.

Exemplo:
Ingrediente: Salmão
Sugestão -> Tartar de salmão fresco com molho cítrico e torradas de brioche
"""

user_prompt = "Cogumelos"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("\n=== One Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === One Shot ===
# Resposta: **Ingrediente:** Cogumelos
#
# **Sugestão:** *Ravioli de massa de espinafre recheado com duxelles de cogumelos silvestres, finalizado com espuma
# de vinho branco, lascas de trufa negra e um toque de manteiga de sálvia crocante.*
#
# *Descrição:* A massa delicada de espinafre envolve um recheio rico de cogumelos chanterelle, porcini e shiitake,
# previamente refogados com chalotas e um leve toque de creme. O prato é servido com uma espuma aveludada de vinho
# branco que realça a terra dos cogumelos, enquanto as lascas de trufa negra trazem perfume e profundidade. Por fim,
# a manteiga de sálvia crocante adiciona textura e um aroma herbáceo que completa a experiência gastronômica
# sofisticada.

# %% [markdown]
# ### Few Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.

<exemplos>
Ingrediente: Tomate
Sugestão <-> Carpaccio de tomate com azeite trufado e manjericão fresco

Ingrediente: Chocolate
Sugestão <-> Soufflé de chocolate meio amargo com calda de frutas vermelhas

Ingrediente: Batata
Sugestão <-> Nhoque artesanal de batata ao molho de manteiga e sálvia
</exemplos>
"""

user_prompt = "Camarão"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("\n=== Few Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Few Shot ===
# Resposta: Ingrediente: Camarão
# Sugestão <-> Camarão ao risoto de açafrão com crocante de pistache, finalizado com espuma de manteiga de ervas e
# redução de vinagre balsâmico envelhecido.

# %% [markdown]
# ### Few Shot Criativo

# %%
system_prompt = """
Você é um chef criativo que mistura ingredientes improváveis em pratos sofisticados.

Exemplos:
Combinação: Manga + Pimenta
Prato -> Ceviche de manga apimentado com chips de batata doce

Combinação: Café + Laranja
Prato -> Entrecôte ao molho de café e raspas de laranja

Combinação: Queijo azul + Melancia
Prato -> Salada refrescante de melancia com queijo azul e nozes
"""

user_prompt = "Combinação: Morango + Manjericão"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.7
)

print("\n=== Few Shot Criativo ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Few Shot Criativo ===
# Resposta: **Prato:** *Carpaccio de Morango com “Caviar” de Manjericão, Redução de Vinagre de Framboesa e Crocante
# de Pistache*
#
# ---
#
# ### Descrição
# Um prato leve e elegante que celebra a doçura fresca do morango ao lado do perfume herbáceo do manjericão. As
# fatias finíssimas de fruta são dispostas como um carpaccio, cobertas por pequenas pérolas de “caviar” de manjericão
# que explodem em aroma ao ser mordidas. A redução de vinagre de framboesa traz acidez frutada, enquanto o crocante
# de pistache oferece textura e um toque de amargor que equilibra o conjunto.
#
# ---
#
# ## Ingredientes (para 4 porções)
#
# | Ingrediente | Quantidade |
# |-------------|------------|
# | Morangos frescos, maduros | 400 g |
# | Manjericão fresco | 30 g (folhas + 10 g para o “caviar”) |
# | Vinagre de framboesa* | 80 ml |
# | Açúcar mascavo | 20 g |
# | Água | 30 ml |
# | Pistache sem casca, torrado e picado | 30 g |
# | Sal marinho grosso | a gosto |
# | Pimenta rosa em grãos, levemente moída | a gosto |
# | Óleo de oliva extra‑virgem | 2 ml (para finalizar) |
# | Folhas de micro‑verdura (opcional) | 4 ramas |
#
# \*Vinagre de framboesa pode ser preparado em casa: 100 ml de vinagre de vinho branco + 30 g de framboesas frescas,
# leve ao fogo até reduzir ½ e coe.
#
# ---
#
# ## Técnicas
#
# ### 1. Carpaccio de Morango
# 1. Lave os morangos, retire as folhas e seque bem.
# 2. Congele-os por 10 min (facilita o corte).
# 3. Com uma faca de sashimi bem afiada, fatie os morangos o mais fino possível (0,3 mm a 0,5 mm).
# 4. Disponha as fatias em um prato raso, formando um leito uniforme, levemente sobreposto.
#
# ### 2. “Caviar” de Manjericão (esferificação simples)
# 1. **Gel de manjericão:** Bata 10 g de folhas de manjericão com 20 ml de água filtrada e 2 g de agar‑agar. Cozinhe
# 1 minuto em fogo médio, depois deixe esfriar a 40 °C.
# 2. **Esferificação:** Use uma seringa ou pipeta para pingar pequenas gotas (≈2 mm) da solução gelificada sobre uma
# superfície fria (prato de cerâmica gelado ou bandeja de gelo). As gotas solidificam instantaneamente, formando
# pérolas translúcidas.
# 3. Reserve na geladeira até o momento de montar o prato.
#
# ### 3. Redução de Vinagre de Framboesa
# 1. Em uma panela pequena, misture o vinagre de framboesa, o açúcar mascavo e a água.
# 2. Leve ao fogo baixo, mexendo até o açúcar dissolver.
# 3. Deixe reduzir até obter uma consistência de xarope leve (cerca de 5 min).
# 4. Passe por uma peneira fina e deixe esfriar.
#
# ### 4. Crocante de Pistache
# 1. Em uma frigideira seca, toste levemente os pistaches picados até dourarem (cerca de 2 min).
# 2. Deixe esfriar e, em seguida, triture grosseiramente para obter pedaços crocantes.
#
# ---
#
# ## Montagem
#
# 1. **Carpaccio** – Regue levemente o leito de morangos com 1 ml de azeite de oliva e uma pitada de sal marinho
# grosso.
# 2. **Caviar** – Distribua delicadamente as pérolas de manjericão sobre o carpaccio (cerca de 8–10 por porção).
# 3. **Redução** – Use um conta‑gotas ou uma colher de chá para pingar a redução de vinagre de framboesa ao redor do
# prato, criando fios artísticos.
# 4. **Crocante** – Salpique o pistache torrado por cima, garantindo contraste de textura.
# 5. **Finalização** – Polvilhe levemente pimenta rosa moída e, se desejar, decore com uma raminha de micro‑verdura
# para cor.
#
# ---
#
# ## Dicas de Chef
#
# - **Temperatura dos morangos:** Mantê‑los bem frios (mas não congelados) realça a firmeza ao cortar e impede que o
# suco escorra demais.
# - **Esferificação sem cálcio:** A técnica acima usa agar‑agar, evitando a necessidade de banho de cálcio. Se quiser
# uma esfera mais “gelatinosa”, substitua por alginato + banho de cálcio, mas o agar dá uma textura mais firme e
# brilhante.
# - **Equilíbrio de sabores:** Prove a redução antes de finalizar; ela deve ser ácida o suficiente para cortar a
# doçura dos morangos, mas não tão agressiva a ponto de sobrepor o manjericão.
# - **Apresentação:** Um prato de cerâmica branca ou de pedra natural realça as cores vibrantes do vermelho dos
# morangos e o verde das pérolas de manjericão.
#
# ---
#
# **Resultado:** Um amuse‑bouche ou entrada de alta gastronomia que surpreende o paladar com camadas de sabor — doce,
# herbáceo, ácido e crocante — tudo em uma apresentação visualmente impactante. Bon appétit!

# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Saída em Formato de Tabela

# %%
system_prompt = """
Você é um historiador especializado em civilizações antigas.
Sempre responda no formato de tabela:

| Civilização | Período | Contribuição Marcante | Região |
|-------------|---------|-----------------------|--------|
"""

user_prompt = "Crie uma tabela comparando 4 civilizações antigas (Egito, Mesopotâmia, Grécia, Roma)."

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    
    temperature=0.5
)

print(response.choices[0].message.content)
# Out:
# | Civilização | Período | Contribuição Marcante | Região |
# |-------------|---------|-----------------------|--------|
# | Egito | c. 3100 a.C. – 30 a.C. | Escrita hieroglífica, arquitetura monumental (pirâmides, templos) e avanços em
# medicina e engenharia hidráulica | Vale do Nilo, Norte‑África |
# | Mesopotâmia | c. 3500 a.C. – 539 a.C. | Invenção da escrita cuneiforme, códigos legais (Código de Hamurabi) e
# desenvolvimento da astronomia e matemática | Entre os rios Tigre e Eufrates (atual Iraque) |
# | Grécia | c. 800 a.C. – 146 a.C. | Bases da filosofia, ciência, democracia ateniense e artes clássicas (teatro,
# escultura) | Península Balcânica, ilhas do Egeu e costas da Ásia Menor |
# | Roma | c. 753 a.C. – 476 d.C. (Ocidental) | Direito romano, engenharia (aquedutos, estradas, concreto) e
# administração de um vasto império | Península Itálica e, posteriormente, Europa, Norte da África e Oriente Médio |

# %% [markdown]
# ### Saída em uma Lista Simples

# %%
system_prompt_simples = "Você é um crítico de cinema que apresenta informações em listas claras."
user_prompt_simples = "Liste 5 filmes premiados no Oscar que marcaram a história do cinema."

response_simples = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_simples},
        {"role": "user", "content": user_prompt_simples}
    ],
    temperature=0.6
)
print(response_simples.choices[0].message.content)
print()
# Out:
# **5 filmes premiados no Oscar que marcaram a história do cinema**
#
# | Filme | Ano de lançamento | Principais Oscars (categorias) | Por que é histórico |
# |-------|-------------------|--------------------------------|----------------------|
# | **Cidadão Kane** (Citizen Kane) | 1941 | Melhor Roteiro Original, Melhor Fotografia (preto‑branco) | Revolucionou
# a narrativa e a linguagem visual (deep focus, montagem não‑linear). |
# | **Casablanca** | 1942 | Melhor Filme, Melhor Diretor (Michael Curtiz), Melhor Roteiro Adaptado, Melhor Fotografia
# (preto‑branco) | Definiu o romance de guerra e tornou-se referência de diálogos icônicos. |
# | **...E o Vento Levou** (Gone with the Wind) | 1939 | Melhor Filme, Melhor Diretor (Victor Fleming), Melhor Atriz
# (Vivien Leigh), entre outros (total 8 estatuetas) | Primeiro grande épico em Technicolor; quebrou recordes de
# bilheteria e influenciou a produção de filmes de época. |
# | **O Poderoso Chefão** (The Godfather) | 1972 | Melhor Filme, Melhor Ator (Marlon Brando), Melhor Roteiro
# Adaptado, Melhor Direção de Arte | Redefiniu o gênero de máfia, introduzindo um drama familiar profundo e estética
# sombria. |
# | **Titanic** | 1997 | 11 Oscars (incluindo Melhor Filme e Melhor Direção – James Cameron) | Demonstrou o potencial
# dos efeitos digitais combinados a narrativas épicas; quebrou recordes de bilheteria e de premiações. |
#
# *Obs.: a lista combina diferentes épocas, gêneros e inovações técnicas, mostrando como o Oscar reconheceu obras que
# transformaram a linguagem cinematográfica.*
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Lista Numerada

# %%
system_prompt_numerada = """
Você cria listas numeradas no formato:
1. [Título]: [Descrição curta]
"""
user_prompt_numerada = "Liste 4 estratégias de treinamento usadas por atletas olímpicos."

response_numerada = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_numerada},
        {"role": "user", "content": user_prompt_numerada}
    ],
    max_completion_tokens=200,
    temperature=0.6
)
print(response_numerada.choices[0].message.content)
print()
# Out:
# 1. **Treinamento em Altitude**: Exercícios realizados em ambientes de alta altitude para melhorar a capacidade de
# transporte de oxigênio e a resistência aeróbica.
# 2. **Periodização de Carga**: Planejamento estruturado que varia intensidade, volume e tipo de treino ao longo do
# ano para otimizar picos de performance.
# 3. **Treinamento Funcional Específico**: Uso de movimentos que replicam as demandas da modalidade, focando em
# força, agilidade e coordenação integradas.
# 4. **Recuperação Ativa e Terapias Regenerativas**
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Lista Hierárquica

# %%
system_prompt_hierarquica = """
Você organiza informações em listas hierárquicas no formato:
• Categoria Principal
  - Subcategoria 1
  - Subcategoria 2
"""
user_prompt_hierarquica = "Organize áreas da ciência em categorias: Física, Biologia, Química."

response_hierarquica = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_hierarquica},
        {"role": "user", "content": user_prompt_hierarquica}
    ],
    temperature=0.6
)
print(response_hierarquica.choices[0].message.content)
# Out:
# • Física
#   - Mecânica Clássica
#   - Termodinâmica
#   - Eletromagnetismo
#   - Física Quântica
#   - Física de Partículas
#   - Astrofísica
#   - Física de Materiais
#
# • Biologia
#   - Genética
#   - Ecologia
#   - Microbiologia
#   - Biologia Celular
#   - Evolução
#   - Fisiologia
#   - Biotecnologia
#
# • Química
#   - Química Orgânica
#   - Química Inorgânica
#   - Química Analítica
#   - Química Física
#   - Bioquímica
#   - Química Ambiental
#   - Química dos Materiais

# %% [markdown]
# ### Parágrafos Estruturados

# %%
system_prompt = """
Você escreve textos estruturados no formato:

INTRODUÇÃO: [1-2 frases de contexto]
DESENVOLVIMENTO: [Explicação detalhada]
CONCLUSÃO: [Síntese final]
"""

user_prompt = "Explique a importância da moda como expressão cultural."

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.7
)

print(response.choices[0].message.content)
# Out:
# **INTRODUÇÃO:** A moda vai além da simples vestimenta; ela funciona como um espelho que reflete valores, histórias
# e identidades de uma sociedade.
#
# **DESENVOLVIMENTO:** Como forma de comunicação visual, a moda permite que indivíduos e grupos expressem
# pertencimento a determinadas comunidades, classes sociais, gerações ou movimentos políticos. Cada tendência,
# tecido, corte ou cor carrega significados simbólicos que podem reforçar tradições culturais (como os trajes típicos
# de festivais), contestar normas estabelecidas (como o streetwear que questiona hierarquias) ou celebrar
# transformações sociais (por exemplo, a adoção de estilos gender‑fluid que desafiam binarismos de gênero). Além
# disso, a moda registra processos históricos: as mudanças de silhuetas ao longo das décadas revelam evoluções
# econômicas, tecnológicas e de poder, enquanto a disseminação global de estilos evidencia trocas interculturais e
# apropriações. No âmbito econômico, a indústria da moda gera empregos, impulsiona a criatividade e promove a
# sustentabilidade quando incorpora práticas responsáveis, reforçando, assim, a identidade cultural de regiões que
# valorizam artesanato local.
#
# **CONCLUSÃO:** Em suma, a moda é uma poderosa linguagem cultural que articula identidade, história e transformação
# social, servindo tanto como preservadora de tradições quanto como agente de mudança e diálogo entre diferentes
# povos.

# %% [markdown]
# ### Formato Customizado

# %%
system_prompt_card = """
Você cria cards informativos sobre missões espaciais no formato:

🚀 MISSÃO: [Nome]
📅 ANO: [Ano]
🌌 OBJETIVO: [Resumo em 1 frase]
🔭 RESULTADO: [Principais descobertas]
"""
user_prompt_card = "Crie um card sobre a missão Voyager 1."

response_card = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_card},
        {"role": "user", "content": user_prompt_card}
    ],
    temperature=0.6
)
print(response_card.choices[0].message.content)
print()
# Out:
# 🚀 MISSÃO: Voyager 1
# 📅 ANO: 1977
# 🌌 OBJETIVO: Explorar Júpiter, Saturno e o espaço interestelar, enviando dados sobre os planetas externos.
# 🔭 RESULTADO: Primeira sonda a sobrevoar Júpiter e Saturno – revelou vulcões em Io, atmosferas complexas, anéis
# detalhados de Saturno e inúmeras luas – e, em 2012, tornou‑se a primeira a entrar no espaço interestelar, medindo
# partículas e campos magnéticos além da heliosfera; carrega ainda o Disco de Ouro com sons e imagens da Terra.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Formato Checklist

# %%
system_prompt_checklist = """
Você cria checklists no formato:

✅ [Tarefa 1]
✅ [Tarefa 2]
✅ [Tarefa 3]
"""
user_prompt_checklist = "Monte um checklist para organizar um festival de música ao ar livre."

response_checklist = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt_checklist},
        {"role": "user", "content": user_prompt_checklist}
    ],
    max_completion_tokens=400,
    temperature=0.6
)
print(response_checklist.choices[0].message.content)
# Out:
# **Checklist para Organizar um Festival de Música ao Ar Livre**
#
# ---
#
# ### 1️⃣ Planejamento Estratégico
# ✅ Definir objetivo e conceito do festival
# ✅ Escolher data (verificar calendário de eventos e clima)
# ✅ Estabelecer orçamento detalhado
# ✅ Identificar público‑alvo
# ✅ Criar cronograma geral com marcos (milestones)
#
# ### 2️⃣ Local & Infraestrutura
# ✅ Selecionar e reservar o espaço (campo, parque, praia, etc.)
# ✅ Verificar acesso a vias, estacionamento e transporte público
# ✅ Obter licenças e alvarás (uso do solo, eventos, som, álcool, etc.)
# ✅ Contratar empresa de montagem de palco, estruturas e tendas
# ✅ Planejar áreas: palco, camarins, zona de alimentação, banheiros, primeiros‑socorros, backstage, área de camping
# (se houver)
# ✅ Garantir fornecimento de energia elétrica (geradores, rede)
# ✅ Instalar rede de água e esgoto temporária
# ✅ Definir plano de iluminação e sonorização
#
# ### 3️⃣ Programação Artística
# ✅ Levantar e contratar artistas/bandas (headliners e apoio)
# ✅ Negociar cachês, rider técnico e rider de hospitalidade
# ✅ Definir ordem de apresentações e tempo de set
# ✅ Contratar agentes de booking ou produtor musical
# ✅ Organizar ensaios e soundcheck
#
# ### 4️⃣ Logística & Operações
# ✅ Contratar empresa de montagem/desmontagem de palco e estruturas
# ✅ Planejar transporte de equipamentos (c

# %% [markdown]
# ### Unindo tudo

# %%
system_prompt = """
Você cria relatórios executivos no formato:

📊 RESUMO
[Resumo em 2-3 frases]

📈 DESTAQUES
1. [Ponto-chave 1]
2. [Ponto-chave 2]
3. [Ponto-chave 3]

💡 RECOMENDAÇÕES
• Curto prazo: [Ação imediata]
• Médio prazo: [Ação estratégica]
• Longo prazo: [Visão futura]
"""

user_prompt = """
Crie um relatório executivo sobre os impactos da exploração de Marte para a economia global.
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    max_completion_tokens=700,
    temperature=0.6
)

print(response.choices[0].message.content)
# Out:
# 📊 **RESUMO**
# A exploração de Marte está impulsionando novos setores tecnológicos, gerando empregos de alta qualificação e
# estimulando investimentos em infraestrutura espacial. Embora os custos iniciais sejam elevados, os benefícios
# econômicos de longo prazo — como inovações em energia, materiais e telecomunicações — prometem transformar a
# economia global.
#
# 📈 **DESTAQUES**
# 1. **Cadeia de suprimentos avançada** – O desenvolvimento de foguetes reutilizáveis, habitats pressurizados e
# sistemas de suporte à vida cria demandas para materiais compostos, impressão 3D e robótica, ampliando mercados
# industriais.
# 2. **Inovação tecnológica transferível** – Tecnologias de energia (p. ex., baterias de alta densidade, energia
# nuclear compacta) e comunicação (laser de alta velocidade) desenvolvidas para Marte têm aplicações imediatas em
# energia renovável e internet global.
# 3. **Novo ecossistema de investimento** – Fundos de capital de risco e agências governamentais estão alocando
# bilhões em startups espaciais, gerando um “cluster” de empresas que atrai talentos e estimula a competitividade
# internacional.
#
# 💡 **RECOMENDAÇÕES**
# - **Curto prazo:** Criar incentivos fiscais e subsídios direcionados a P&D de tecnologias críticas (propulsão,
# materiais, IA) para acelerar a transferência de know‑how para setores civis.
# - **Médio prazo:** Estabelecer parcerias público‑privadas que financiem infraestruturas de lançamento e plataformas
# de teste em órbita baixa, reduzindo custos de acesso ao espaço e ampliando a base de fornecedores.
# - **Longo prazo:** Desenvolver uma agenda regulatória internacional que padronize a mineração e a produção em
# Marte, garantindo sustentabilidade, segurança jurídica e distribuição equitativa dos benefícios econômicos.

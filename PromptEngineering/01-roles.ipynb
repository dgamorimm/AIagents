# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Compreendendo os Roles

# %% [markdown]
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# **LLM (Large Language Model)** – ou **Grande Modelo de Linguagem** – é um tipo de inteligência artificial treinada
# em enormes quantidades de texto (bilhões de palavras) para aprender padrões, gramática, fatos e até estilos de
# escrita.
#
# - **Como funciona?** Usa redes neurais do tipo *transformer*, que processam palavras em paralelo e capturam
# relações de longo alcance entre elas.
# - **O que faz?** Gera texto coerente, responde perguntas, traduz, resume, cria códigos, entre outras tarefas de
# linguagem natural.
# - **Por que “large”?** O “large” vem tanto do tamanho do modelo (milhões a centenas de bilhões de parâmetros)
# quanto da quantidade massiva de dados de treinamento.
#
# Em resumo, uma LLM é um modelo de IA que, após aprender com muito texto, consegue entender e produzir linguagem
# humana de forma bastante sofisticada.

# %% [markdown]
# ### Definindo um comportamento para modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# As **LLMs (Large Language Models)** são modelos de inteligência artificial treinados com enormes quantidades de
# texto para prever a próxima palavra em uma sequência.
# - **Escala**: possuem bilhões a trilhões de parâmetros, que são os “ajustes” que o modelo aprende.
# - **Treinamento**: usam aprendizado não supervisionado (ou auto‑supervisionado), absorvendo padrões gramaticais,
# fatos, raciocínios e estilos de escrita presentes nos dados.
# - **Capacidades**: geram textos coerentes, respondem perguntas, traduzem, resumem, codificam, entre outras tarefas
# de linguagem natural, muitas vezes sem necessidade de ajuste fino específico.
# - **Limitações**: podem produzir informações imprecisas ou tendenciosas, não têm compreensão real do mundo e
# dependem da qualidade dos dados de treinamento.

# %% [markdown]
# ### Controlando Resposta do Modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        },
        {
            "role": "assistant",
            "content": "LLMs com baixa latência permitem respostas mais rápidas, o que melhora a experiência do usuário."
        },
        {
            "role": "user",
            "content": "Pode dar exemplos de aplicações práticas?"
        }
    ],
    model="openai/gpt-oss-120b",
)

print(chat_completion.choices[0].message.content)
# Out:
# ### Aplicações práticas que exigem baixa latência em LLMs
#
# | Área | Por que a latência baixa é crítica | Exemplo concreto |
# |------|-----------------------------------|-------------------|
# | **Assistentes de voz / chatbots** | Usuário espera resposta quase instantânea; atrasos acima de ~300 ms já são
# percebidos como “lento”. | *Assistente virtual de um call‑center que entende a fala do cliente e responde em tempo
# real, ajudando a resolver problemas sem colocar o cliente em espera.* |
# | **Sistemas de recomendação em tempo real** | Recomendações precisam ser geradas enquanto o usuário navega ou faz
# a última interação. | *E‑commerce que sugere produtos ao usuário logo após ele clicar em um item, usando um LLM
# para personalizar a descrição ou o motivo da sugestão.* |
# | **Ferramentas de produtividade (code‑assist, escrita, planilhas)** | Interrupções prolongadas atrapalham o fluxo
# de trabalho. | *Extensão de IDE que completa código enquanto o programador digita, ou um plugin de e‑mail que gera
# respostas em poucos milissegundos.* |
# | **Jogos e realidade aumentada/virtual** | Decisões de NPCs ou diálogos gerados dinamicamente precisam ser quase
# imediatos para manter a imersão. | *Personagem de RPG que reage a perguntas do jogador usando um LLM; atraso maior
# que 200 ms quebra a sensação de conversa natural.* |
# | **Finanças e trading algorítmico** | Cada milissegundo pode significar diferença entre lucro e perda. | *Chat‑bot
# que interpreta notícias financeiras e gera insights de risco em tempo real, alimentando um motor de decisão de
# compra/venda.* |
# | **Monitoramento e alertas de segurança** | Respostas rápidas podem impedir incidentes. | *Sistema que analisa
# logs em tempo real e gera recomendações de mitigação imediatamente ao detectar um padrão suspeito.* |
# | **Saúde e telemedicina** | Decisões clínicas precisam ser entregues com rapidez, principalmente em triagens. |
# *Assistente que interpreta sintomas digitados por um paciente e sugere próximos passos em segundos, permitindo ao
# médico focar no diagnóstico.* |
# | **Automação de atendimento ao cliente (RPA)** | Bots que preenchem formulários ou executam tarefas precisam
# concluir a ação antes que o usuário mude de tela. | *RPA que recebe uma solicitação de suporte, preenche
# automaticamente um ticket e devolve a confirmação em < 500 ms.* |
#
# ---
#
# #### Por que a latência baixa faz diferença?
#
# 1. **Experiência do usuário (UX)** – A percepção de fluidez aumenta a satisfação e a adoção do serviço.
# 2. **Conversão e retenção** – Em e‑commerce ou aplicativos, respostas rápidas elevam taxas de conversão e diminuem
# abandonos.
# 3. **Custo operacional** – Menor tempo de processamento permite maior throughput com a mesma infraestrutura.
# 4. **Segurança e compliance** – Em ambientes críticos (financeiro, saúde), atrasos podem violar SLAs ou
# regulamentos.
# 5. **Imersão** – Em entretenimento interativo, a latência afeta diretamente a sensação de realismo.
#
# ---
#
# #### Estratégias para alcançar baixa latência
#
# - **Modelos otimizados**: usar variantes quantizadas, pruned ou distiladas (ex.: DistilGPT, LLaMA‑2‑7B‑int8).
# - **Inferência na borda**: rodar o modelo próximo ao usuário (edge computing) para eliminar a ida‑e‑volta ao
# data‑center.
# - **Serviços de “prefetching”**: antecipar consultas prováveis e manter respostas em cache.
# - **Pipeline de hardware acelerado**: GPUs de última geração, TPUs ou ASICs especializados.
# - **Batching inteligente**: agrupar requisições sem sacrificar o tempo de resposta individual.
#
# Esses exemplos mostram como a baixa latência em LLMs deixa a diferença entre um produto “bom” e um produto que
# realmente entrega valor em tempo real.

# %% [markdown]
# ### Usando System Prompt Refinados

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "Você é um especialista em Inteligência Artificial focado em explicar conceitos "
                "de forma clara, estruturada e prática. Sempre inicie suas respostas com um "
                "resumo em até 3 linhas, depois detalhe com exemplos reais e aplicações no mundo "
                "dos negócios e tecnologia. Evite termos excessivamente técnicos sem explicação "
                "e, quando necessário, use analogias simples. "
                "Se o usuário pedir código, forneça exemplos em Python bem comentados."
            ),
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        }
    ],
    model="openai/gpt-oss-120b",
)

print(chat_completion.choices[0].message.content)
# Out:
# **Resumo:**
# LLMs (Large Language Models) com baixa latência respondem quase que instantaneamente, o que torna a interação
# fluida, aumenta a produtividade e abre oportunidades em tempo real nos negócios e na tecnologia.
#
# ---
#
# ## Por que a latência baixa é crucial?
#
# | Aspecto | O que significa | Impacto prático |
# |---|---|---|
# | **Experiência do usuário** | Respostas em milissegundos, como conversar com alguém ao vivo. | Clientes ficam mais
# satisfeitos, reduzindo desistências em chatbots ou assistentes virtuais. |
# | **Produtividade interna** | Ferramentas que sugerem textos, códigos ou insights imediatamente. | Equipes de
# suporte, vendas ou desenvolvimento gastam menos tempo esperando respostas e entregam resultados mais rápido. |
# | **Processos críticos em tempo real** | Decisões que precisam ser tomadas em frações de segundo (ex.:
# monitoramento de fraudes). | Atrasos podem significar perdas financeiras ou riscos de segurança. |
# | **Escalabilidade econômica** | Servidores que entregam respostas rápidas usam recursos de forma mais eficiente. |
# Menor custo por consulta, permitindo oferecer IA como serviço (API) a preços competitivos. |
#
# ---
#
# ## Exemplos reais
#
# ### 1. **Chatbots de e‑commerce**
# - **Problema:** Um cliente que está quase finalizando a compra tem dúvidas sobre o prazo de entrega. Se o chatbot
# demora 3 s para responder, o cliente pode abandonar o carrinho.
# - **Solução com baixa latência:** Resposta em < 200 ms mantém a conversa fluida, aumenta a taxa de conversão em até
# 15 % (dados de experimentos da Shopify).
#
# ### 2. **Assistentes de código para desenvolvedores**
# - **Problema:** Um programador usa um “copilot” que sugere linhas de código. Se a sugestão chega com atraso, ele
# perde o ritmo de escrita.
# - **Solução:** Latência < 500 ms mantém o fluxo criativo; estudos da Microsoft mostram que a produtividade pode
# subir 30 % quando a latência está abaixo desse ponto.
#
# ### 3. **Detecção de fraude em transações financeiras**
# - **Problema:** Cada milissegundo conta; se o modelo de risco leva 2 s para analisar uma transação, o cliente pode
# receber um “erro” e tentar outra via outro canal, aumentando o risco.
# - **Solução:** Modelos otimizados (quantização, inferência em GPU/TPU) entregam decisões em < 50 ms, permitindo
# bloqueio imediato e evitando perdas.
#
# ### 4. **Aplicações de voz em dispositivos IoT**
# - **Problema:** Um assistente de voz em um carro precisa compreender comandos enquanto o motorista dirige. Latência
# alta pode causar distração.
# - **Solução:** Modelos de linguagem com resposta em < 100 ms garantem que o comando “ligar ar-condicionado” seja
# executado quase que instantaneamente, melhorando segurança.
#
# ---
#
# ## Como alcançar baixa latência?
#
# 1. **Modelos menores ou “distilados”** – versões compactas que mantêm boa qualidade, mas são mais leves.
# 2. **Quantização** – converter pesos de ponto flutuante (32 bits) para inteiros de 8 bits, reduzindo o tamanho e
# acelerando cálculos.
# 3. **Inferência em hardware especializado** – GPUs, TPUs ou aceleradores de IA (ex.: NVIDIA TensorRT, Google Edge
# TPU).
# 4. **Cache de respostas** – armazenar respostas para perguntas frequentes e reutilizar, evitando recomputação.
# 5. **Pipeline assíncrono** – dividir a solicitação em etapas (pré‑processamento, inferência, pós‑processamento) que
# rodam em paralelo.
#
# ---
#
# ## Aplicações no mundo dos negócios
#
# - **Serviços SaaS de IA:** Oferecer APIs com SLA de < 100 ms diferencia o provedor no mercado.
# - **Suporte ao cliente:** Equipes de help desk podem automatizar respostas, liberando agentes para casos complexos.
# - **Marketing personalizado:** Geração de copy em tempo real para anúncios dinâmicos, permitindo testes A/B
# instantâneos.
# - **Educação digital:** Tutores virtuais que respondem imediatamente mantêm o ritmo de aprendizado dos estudantes.
#
# ---
#
# ## Analogia simples
#
# Imagine que você está em um restaurante e o garçom traz seu pedido em 30 minutos vs. 30 segundos. O segundo caso
# faz você se sentir valorizado e satisfeito, enquanto o primeiro pode fazer você desistir da refeição. LLMs de baixa
# latência são como o garçom rápido: entregam “o prato” (a resposta) no momento exato em que o cliente (usuário ou
# sistema) precisa.
#
# ---
#
# ### Conclusão
#
# A latência baixa transforma LLMs de ferramentas de consulta em parceiros de decisão em tempo real, impulsionando a
# experiência do usuário, a eficiência operacional e a competitividade de produtos e serviços. Investir em
# otimizações de modelo e hardware não é apenas uma questão técnica, mas um diferencial estratégico no mercado atual.

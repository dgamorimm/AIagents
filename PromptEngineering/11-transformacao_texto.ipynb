# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# - **Transformação de formato** → mudança de estrutura
# - **Transformação de tom** → ajuste de estilo
# - **Transformação de perspectiva** → mudança de ponto de vista
# - **Adaptação para público** → linguagem adequada ao leitor

# %% [markdown]
# ### Transformação de Formato

# %%
system_prompt = """
Você é um especialista em formatação de conteúdo.
Transforme textos entre diferentes estruturas garantindo:
1) Clareza
2) Preservação das informações originais
3) Boa organização
"""

user_prompt = """
Transforme este parágrafo em uma receita passo a passo:

"Para preparar um bom café gelado, você deve moer grãos de café fresco, preparar um café forte,
deixar esfriar, adicionar gelo em um copo alto e completar com leite ou creme a gosto.
Finalize com um toque de açúcar ou xarope de baunilha."
"""

response_format = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.3
)

print("=== RESULTADO (Formato) ===")
print(response_format.choices[0].message.content)
# Out:
# === RESULTADO (Formato) ===
# **Receita de Café Gelado**
#
# **Ingredientes**
# - Grãos de café fresco
# - Água quente
# - Gelo (cubo ou picado)
# - Leite ou creme (a gosto)
# - Açúcar ou xarope de baunilha (opcional)
#
# **Modo de preparo**
#
# 1. **Moer o café**
#    - Use uma moagem média‑fina para garantir boa extração.
#
# 2. **Preparar um café forte**
#    - Meça a quantidade de café moído (aprox. 2 colheres de sopa para 200 ml de água).
#    - Despeje água quase fervente (cerca de 95 °C) sobre o café e deixe extrair por 3–4 minutos.
#
# 3. **Resfriar o café**
#    - Transfira o café quente para um recipiente de vidro ou metal.
#    - Deixe esfriar à temperatura ambiente ou acelere o processo colocando o recipiente na geladeira por 10–15 min.
#
# 4. **Montar o copo**
#    - Encha um copo alto com gelo até a metade ou mais, conforme a preferência.
#
# 5. **Adicionar o café gelado**
#    - Despeje o café já frio sobre o gelo, preenchendo o copo quase até o topo.
#
# 6. **Completar com leite ou creme**
#    - Acrescente leite ou creme a gosto (aprox. 30‑50 ml). Misture delicadamente.
#
# 7. **Finalizar com adoçante**
#    - Se desejar, adicione açúcar ou xarope de baunilha a gosto. Mexa novamente para incorporar.
#
# 8. **Servir**
#    - Sirva imediatamente, com canudo ou colher, e aproveite seu café gelado refrescante!

# %% [markdown]
# ### Transformação de Tom

# %%
system_prompt = """
Você é um especialista em adaptação de estilo.
Transforme textos mudando o tom sem perder o sentido.
"""

user_prompt = """
Transforme este texto jornalístico em um post leve para redes sociais:

"A cidade de Lisboa recebeu mais de 4 milhões de turistas em 2024,
consolidando-se como um dos destinos mais procurados da Europa."
"""

response_tone = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6
)

print("\n=== RESULTADO (Tom) ===")
print(response_tone.choices[0].message.content)
# Out:
# === RESULTADO (Tom) ===
# 🌍✈️ Lisboa bombando! Em 2024, a capital portuguesa recebeu **mais de 4 milhões de visitantes**. Não é à toa que a
# cidade está entre os destinos mais desejados da Europa! 🇵🇹💙 #Lisboa #Turismo #Viagem #Europa #DestinoTop

# %% [markdown]
# ### Transformação de Ponto de Vista

# %%
system_prompt = """
Você é um especialista em narrativa.
Reescreva o texto mudando o ponto de vista.
"""

user_prompt = """
Transforme de primeira para terceira pessoa:

"Eu viajei para o Japão pela primeira vez em 2023 e fiquei impressionado
com a mistura de tradição e tecnologia em Tóquio."
"""

response_perspective = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("\n=== RESULTADO (Perspectiva) ===")
print(response_perspective.choices[0].message.content)
# Out:
# === RESULTADO (Perspectiva) ===
# Ele viajou para o Japão pela primeira vez em 2023 e ficou impressionado com a mistura de tradição e tecnologia em
# Tóquio.

# %% [markdown]
# ### Múltiplas Transformações

# %%
texto_original = """
"O restaurante Verde Sabor lançou um cardápio 100% sustentável,
com ingredientes locais, redução de plástico e incentivo a fornecedores regionais.
A proposta busca unir gastronomia, saúde e responsabilidade ambiental."
"""

print("=== TEXTO ORIGINAL ===")
print(texto_original)

# %%
# Versão para negócios
business_prompt = f"""
Reescreva este texto para empresários do setor de alimentação, 
focando em inovação e competitividade:\n\n{texto_original}"""

response_business = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": business_prompt}],
    temperature=0.5
)

print("\n=== VERSÃO PARA NEGÓCIOS ===")
print(response_business.choices[0].message.content)
# Out:
# === TEXTO ORIGINAL ===
# "O restaurante Verde Sabor lançou um cardápio 100% sustentável,
# com ingredientes locais, redução de plástico e incentivo a fornecedores regionais.
# A proposta busca unir gastronomia, saúde e responsabilidade ambiental."
# === VERSÃO PARA NEGÓCIOS ===
# **Inovação e Competitividade no Setor de Alimentação**
#
# O restaurante **Verde Sabor** acabou de lançar um cardápio **100 % sustentável**, transformando responsabilidade
# ambiental em vantagem estratégica. A iniciativa inclui:
#
# - **Ingredientes locais de alta qualidade** – redução de custos logísticos, frescor garantido e fortalecimento da
# cadeia de suprimentos regional.
# - **Eliminação de plásticos** – embalagens reutilizáveis e compostáveis que atendem à crescente demanda dos
# consumidores por práticas eco‑friendly.
# - **Parcerias com fornecedores regionais** – criação de um ecossistema colaborativo que gera descontos por volume,
# fideliza parceiros e diferencia a marca no mercado.
#
# Essa proposta vai além da gastronomia e da saúde: ela posiciona o Verde Sabor como **líder em inovação**, atrai um
# público cada vez mais consciente e gera novas fontes de receita por meio de:
#
# - **Marketing de propósito** – storytelling autêntico que aumenta o ticket médio e a taxa de retenção de clientes.
# - **Certificações verdes** – potencial para selos de sustentabilidade que abrem portas em canais de distribuição
# premium.
# - **Eficiência operacional** – menor desperdício de alimentos e redução de custos de insumos, ampliando a margem de
# lucro.
#
# Para empresários do segmento alimentício, o modelo Verde Sabor demonstra como a **sustentabilidade pode ser
# transformada em diferencial competitivo**, impulsionando crescimento, reputação e rentabilidade. Invista em
# práticas verdes hoje e colha os benefícios de um mercado que valoriza cada vez mais a inovação responsável.

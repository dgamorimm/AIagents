# %%
from rich.console import Console
import sys
import builtins

console = Console(force_terminal=False, file=sys.__stdout__)

builtins.print = console.print

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Complemento Textual
# - **Expansão de tópicos** → desenvolvimento de pontos em parágrafos
# - **Expansão criativa** → narrativas envolventes
# - **Expansão argumentativa** → justificativas sólidas
# - **Expansão técnica** → explicações detalhadas e exemplos práticos
# - **Expansão de outline** → transformação de estrutura em conteúdo completo

# %% [markdown]
# ### Expansão de tópicos

# %%
system_prompt = """
Você é um especialista em comunicação corporativa.
Expanda tópicos curtos em parágrafos claros que:
1) Desenvolvam cada ideia com exemplos reais
2) Mantenham fluidez e coerência
3) Sejam úteis para profissionais em cargos de liderança
"""

user_prompt = """
Expanda estes tópicos sobre liderança moderna:

• Comunicação transparente
• Gestão de equipes híbridas
• Incentivo à inovação
"""

response_topics = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("\n=== EXPANSÃO DE TÓPICOS ===")
print(response_topics.choices[0].message.content)
# Out:
# === EXPANSÃO DE TÓPICOS ===
# **Comunicação Transparente**
# A comunicação transparente vai além de simplesmente repassar informações; trata‑se de criar um fluxo constante de
# dados claros, verídicos e acessíveis a todos os níveis da organização. Quando os colaboradores sabem o “porquê” das
# decisões estratégicas, eles se sentem mais engajados e confiantes para contribuir. Um exemplo real é a política de
# “open‑door” da **Buffer**, empresa de gestão de redes sociais. A cada trimestre, a fundadora publica um relatório
# financeiro detalhado, incluindo receitas, despesas e até os salários dos funcionários. Essa prática não só elimina
# rumores como também permite que a equipe compreenda as restrições orçamentárias e, assim, proponha soluções mais
# alinhadas ao contexto econômico. Para líderes que desejam adotar essa postura, recomenda‑se: (i) definir canais de
# comunicação (intranet, newsletters, reuniões de alinhamento) e garantir que sejam bidirecionais; (ii) compartilhar
# metas e indicadores de desempenho (KPIs) de forma regular, explicando variações positivas ou negativas; (iii)
# incentivar perguntas abertas e responder com honestidade, mesmo quando a resposta for “ainda não sabemos”. Essa
# transparência cria um ambiente de confiança, reduz a rotatividade e aumenta a velocidade de tomada de decisão, pois
# os colaboradores já possuem o contexto necessário para agir de forma autônoma.
#
# **Gestão de Equipes Híbridas**
# A realidade pós‑pandemia consolidou o modelo híbrido, no qual parte da equipe trabalha remotamente e outra parte
# está presencialmente. Gerir esse cenário requer novas rotinas e ferramentas que garantam coesão, produtividade e
# bem‑estar. A **Microsoft** ilustrou bem essa transição ao implementar o “Hybrid Workplace” – um conjunto de
# diretrizes que inclui: (a) “flex days” onde cada colaborador escolhe dois dias da semana para estar no escritório,
# permitindo que as equipes se encontrem presencialmente para brainstorming, alinhamento de projetos ou celebrações;
# (b) uso de plataformas como Teams e Viva Insights para monitorar carga de trabalho e sinalizar possíveis
# sobrecargas; (c) treinamento de líderes em “liderança à distância”, focado em métricas de output (entregas) ao
# invés de horas presenciais. Para que outros líderes reproduzam esse sucesso, vale adotar: 1) **Rituais de conexão**
# – reuniões rápidas de “check‑in” diárias que incluam todos, independentemente da localização; 2) **Regras claras de
# disponibilidade** – definir horários de “portas abertas” virtuais para que dúvidas sejam resolvidas em tempo real;
# 3) **Equidade de recursos** – garantir que quem trabalha de casa tenha acesso a equipamentos, licenças de software
# e suporte técnico equivalentes aos do escritório; 4) **Medição de resultados** – estabelecer metas mensuráveis (por
# exemplo, entregas de sprint, taxa de bugs) e avaliar o desempenho com base nesses indicadores, evitando vieses de
# proximidade. Essa abordagem ajuda a manter a cultura organizacional viva, reduz a sensação de isolamento e assegura
# que a produtividade não dependa do local físico.
#
# **Incentivo à Inovação**
# Inovar não é mais uma tarefa pontual de departamentos de P&D; tornou‑se responsabilidade de todos os colaboradores.
# Empresas que cultivam um ecossistema de experimentação conseguem lançar produtos mais rapidamente e adaptar-se a
# mudanças de mercado. Um caso emblemático é o **Google**, que instituiu o programa “20 % Time”, permitindo que os
# funcionários dediquem um quinto da sua carga horária a projetos pessoais que possam gerar valor para a companhia.
# Dentre os resultados, surgiram o Gmail, o Google News e o AdSense – soluções que hoje movimentam bilhões de
# dólares. Para líderes que desejam replicar esse mindset, as práticas recomendadas são: 1) **Criar “labs” internos**
# – espaços (físicos ou virtuais) onde equipes multidisciplinares podem prototipar ideias em ciclos curtos de 2 a 4
# semanas; 2) **Implementar um “pipeline de ideias”** – um fluxo estruturado que coleta sugestões (via formulários ou
# apps), as avalia por critérios de viabilidade e impacto, e encaminha as mais promissoras para testes piloto; 3)
# **Premiar o aprendizado, não apenas o sucesso** – reconhecer publicamente experimentos que falharam, mas que
# geraram insights valiosos, incentivando uma cultura de tolerância ao erro; 4) **Alocar orçamento dedicado** –
# reservar um percentual do orçamento anual (geralmente 5 % a 10 %) para projetos de inovação, evitando que a falta
# de recursos seja um obstáculo. Quando esses mecanismos são institucionalizados, os líderes conseguem transformar a
# inovação em um hábito diário, estimulando a criatividade de toda a equipe e mantendo a empresa à frente da
# concorrência.

# %% [markdown]
# ### Expansão Criativa

# %%
system_prompt = """
Você é um escritor criativo. Expanda ideias simples criando:
1) Cenário vívido
2) Personagens interessantes
3) Atmosfera envolvente
"""

user_prompt = """
Expanda esta ideia em uma micro-história:
"Um barista descobre um bilhete misterioso escondido dentro de um saco de café."
"""

response_creative = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.8
)

print("\n=== EXPANSÃO CRIATIVA ===")
print(response_creative.choices[0].message.content)
# Out:
# === EXPANSÃO CRIATIVA ===
# **O Aroma da Revelação**
#
# A luz da manhã filtrava‑se pelas persianas de linho do *Café das Nuvens*, espalhando sombras que dançavam sobre as
# mesas de madeira desgastada. O ar estava carregado de notas terrosas, de torra escura e de um leve perfume de
# baunilha que o dono, o velho relógio de parede, marcava a cada “tic” como se fosse o compasso de uma sinfonia
# silenciosa.
#
# Lúcia, a barista de cabelos curtos tingidos de cobre e olhos que lembravam a espuma de um cappuccino, movia‑se com
# a graça de quem conhece cada grão como um velho amigo. Enquanto o moedor cantava seu zumbido constante, ela pegou o
# último saco de café da estante—um lote recém‑chegado da região de Yirgacheffe, ainda com a etiqueta ainda verde e
# ainda úmida de terra.
#
# Ao abrir o saco, um leve estalo ecoou, como se o próprio café sussurrasse um segredo. Entre as folhas torradas, um
# pedaço de papel amarelado estava dobrado como um origami improvisado. Lúcia puxou‑o com dedos ainda manchados de
# óleo, sentindo a textura áspera da fibra. No papel, escrito à mão com tinta quase desaparecida, havia apenas três
# palavras:
#
# *“Abaixo da ponte, ao cair da noite.”*
#
# O coração de Lúcia disparou como a primeira gota de água que cai num copo de espresso. Ela olhou ao redor: o
# barulho da rua, o tilintar das xícaras, o cheiro de pão recém‑assado. Mas a frase parecia vibrar no ar, como se o
# próprio ambiente conspirasse para puxá‑la para fora daquela rotina.
#
# Sem perder tempo, ela guardou o bilhete no bolso do avental e, ao fechar a porta do café, o sino de bronze soou,
# anunciando o fim da manhã e o início de algo inesperado. As calçadas molhadas refletiam o céu cinzento; o vento
# soprava levemente, trazendo o som distante de um rio que corria sob a ponte da velha fábrica, agora coberta de
# trepadeiras.
#
# Quando a noite chegou, Lúcia caminhou até a ponte, onde as lâmpadas pálidas lançavam círculos de luz sobre a água.
# O murmúrio do rio era um sussurro que se misturava ao eco das suas botas na pedra. Aproximou‑se da grade e, ao
# olhar para o reflexo, viu algo que não estava lá antes: uma caixa de metal enferrujada, presa ao fundo da ponte,
# como se esperasse ser descoberta.
#
# Com as mãos ainda trêmulas, Lúcia puxou a caixa e a abriu. Dentro, havia um pequeno frasco de vidro contendo grãos
# de café ainda verdes, ainda crus, e um bilhete final, desta vez escrito em caligrafia mais nítida:
#
# *“Para quem tem coragem de seguir o aroma, o futuro é uma xícara cheia.”*
#
# Lúcia sorriu. Naquele instante, o barulho da cidade se transformou em um murmúrio de possibilidades. Ela voltou ao
# *Café das Nuvens* com o frasco nas mãos, pronta para torrefazer aqueles grãos misteriosos e criar, naquela xícara,
# não só um café, mas a história de quem ousa ouvir o sussurro dos segredos escondidos nas sombras do cotidiano.

# %% [markdown]
# ### Expansão Argumentativa

# %%
system_prompt = """
Você é um consultor estratégico.
Expanda argumentos básicos incluindo:
1) Justificativas bem fundamentadas
2) Exemplos e dados de apoio
3) Consideração de contrapontos
4) Conclusão persuasiva
"""

user_prompt = """
Expanda este argumento:
"As empresas devem adotar a semana de trabalho de 4 dias."
"""

response_argument = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.3
)

print("\n=== EXPANSÃO ARGUMENTATIVA ===")
print(response_argument.choices[0].message.content)
# Out:
# === EXPANSÃO ARGUMENTATIVA ===
# **Argumento Expandido: “As empresas devem adotar a semana de trabalho de 4 dias.”**
#
# ---
#
# ## 1. Justificativas bem fundamentadas
#
# | Área | Fundamentação | Por que isso sustenta a adoção da semana de 4 dias |
# |------|----------------|---------------------------------------------------|
# | **Produtividade** | Estudos mostram que a produtividade não é linear em relação ao número de horas trabalhadas.
# Quando os colaboradores têm menos tempo, tendem a focar mais, eliminar distrações e priorizar tarefas de alto
# valor. | A redução de dias cria um “efeito de escassez de tempo”, que aumenta a eficiência e reduz o tempo gasto em
# atividades de baixa relevância. |
# | **Saúde mental e bem‑estar** | A Organização Mundial da Saúde (OMS) associa jornadas extensas a estresse,
# depressão e burnout. Uma pausa extra semanal permite recuperação psicológica e física. | Funcionários mais
# saudáveis apresentam menor absenteísmo, menor rotatividade e maior engajamento. |
# | **Equilíbrio vida‑trabalho** | A cultura de “always‑on” tem sido criticada por prejudicar relações familiares e o
# tempo de lazer. A semana de 4 dias oferece um dia extra para cuidar de filhos, estudos, hobbies ou voluntariado. |
# Quando o colaborador sente que sua vida pessoal é respeitada, ele desenvolve maior lealdade à empresa e maior
# motivação intrínseca. |
# | **Sustentabilidade ambiental** | Menos deslocamentos diários reduzem emissões de CO₂, consumo de energia nos
# escritórios e demanda por recursos (água, papel, etc.). | Empresas que adotam a prática podem usar a redução de
# pegada de carbono como parte de sua estratégia ESG (Environmental, Social, Governance). |
# | **Atração e retenção de talentos** | O mercado de trabalho está cada vez mais competitivo. Benefícios inovadores,
# como a semana de 4 dias, diferenciam a empresa e atraem profissionais qualificados, especialmente as gerações Y e
# Z. | Reduz custos de recrutamento e treinamento, além de melhorar a reputação da marca empregadora. |
# | **Redução de custos operacionais** | Menos dias de funcionamento implicam menor consumo de energia elétrica,
# ar‑condicionado, limpeza, segurança e outros serviços auxiliares. | Economias podem ser reinvestidas em tecnologia,
# capacitação ou remuneração variável. |
#
# ---
#
# ## 2. Exemplos e dados de apoio
#
# 1. **Iceland (2015‑2019)** – Experimento nacional com 2.500 trabalhadores (≈ 1 % da força de trabalho).
#    * **Resultado:** 86 % relatou aumento da produtividade; 89 % manteve ou melhorou a qualidade do trabalho.
#    * **Impacto:** Redução de 25 % nas ausências por doença.
#
# 2. **Microsoft Japão (2019)** – “Summer Friday” – 4‑day week por um mês.
#    * **Resultado:** 40 % de aumento na produtividade medida por tickets resolvidos.
#    * **Economia:** Redução de 23 % nas custos de energia e 59 % nas despesas de impressão.
#
# 3. **Perpetual Guardian (Nova Zelândia, 2018)** – Implementou 4‑day week permanente.
#    * **Resultado:** 20 % de aumento na produtividade; 45 % de redução no estresse percebido; 27 % de diminuição nas
# licenças médicas.
#
# 4. **Relatório da OECD (2022)** – Países que adotam jornadas mais curtas (ex.: Dinamarca, Holanda) apresentam:
#    * **Produtividade por hora trabalhada** 10‑15 % superior à média da OCDE.
#    * **Taxa de desemprego** comparável ou menor, indicando que a redução de horas não gera “desemprego estrutural”.
#
# 5. **Pesquisa da Gallup (2023)** – 71 % dos trabalhadores globais consideram a flexibilidade de horário como o
# principal fator de satisfação no trabalho.
#
# ---
#
# ## 3. Consideração de contrapontos
#
# | Contraponto | Análise crítica | Estratégia de mitigação |
# |-------------|----------------|--------------------------|
# | **Custo de cobertura** – Necessidade de contratar temporários ou pagar horas extras para manter a operação nos 5
# dias. | Em setores críticos (saúde, produção 24h) a cobertura pode ser complexa. | • Implementar escalas rotativas
# de 4 dias entre equipes; <br>• Utilizar tecnologia (automação, IA) para reduzir demandas de suporte; <br>• Negociar
# acordos de trabalho flexível que permitam “work‑from‑home” nos dias de folga. |
# | **Perda de disponibilidade para clientes** – Clientes podem esperar respostas mais lentas. | A percepção de menor
# disponibilidade pode afetar a satisfação. | • Definir “horas de pico” onde a equipe permanece completa; <br>•
# Comunicar claramente ao cliente o novo modelo e garantir SLA (Service Level Agreement) ajustado; <br>• Oferecer
# canais de auto‑serviço (chatbots, FAQs). |
# | **Desigualdade entre funções** – Algumas áreas (ex.: produção em linha) não podem reduzir dias. | Pode gerar
# sensação de injustiça entre colaboradores. | • Aplicar a redução de jornada apenas a funções que permitem, enquanto
# outras recebem compensações (bônus, dias de folga compensatórios, teletrabalho). <br>• Planejar transição gradual,
# começando por departamentos piloto. |
# | **Risco de sobrecarga nos 4 dias** – Expectativa de “trabalhar o mesmo” em menos tempo pode gerar estresse. | Se
# a carga de trabalho não for readequada, o benefício desaparece. | • Redefinir metas e indicadores de performance;
# <br>• Investir em treinamento de gestão de tempo; <br>• Realizar auditorias de processos para eliminar atividades
# redundantes. |
# | **Custo de implementação** – Necessidade de reestruturar políticas, sistemas de ponto, contratos. | Investimento
# inicial pode ser percebido como alto. | • Iniciar com projetos piloto de 3‑6 meses para mensurar ROI; <br>•
# Utilizar métricas claras (produtividade, absenteísmo, custos operacionais) para demonstrar retorno. |
#
# ---
#
# ## 4. Conclusão persuasiva
#
# A adoção da semana de trabalho de 4 dias não é apenas uma moda passageira; é uma estratégia baseada em evidências
# que alinha **produtividade**, **bem‑estar**, **sustentabilidade** e **competitividade**. Os dados de experimentos
# bem‑sucedidos – da Islândia à Microsoft Japão – demonstram ganhos mensuráveis em eficiência e redução de custos, ao
# mesmo tempo em que melhoram a saúde mental dos colaboradores e a imagem ambiental da empresa.
#
# Ao reconhecer e mitigar os desafios (cobertura de serviço, desigualdades setoriais, risco de sobrecarga), as
# organizações podem transformar potenciais obstáculos em oportunidades de inovação organizacional: escalas
# rotativas, automação de processos e políticas de flexibilidade que atendam a todos os stakeholders.
#
# Portanto, **adotar a semana de 4 dias** representa um investimento estratégico de longo prazo:
# * **Retorno financeiro** – menor consumo de recursos e aumento da produtividade por hora.
# * **Retorno humano** – menor turnover, menor absenteísmo e maior engajamento.
# * **Retorno reputacional** – posicionamento como empresa moderna, responsável e atraente para talentos.
#
# Em um cenário econômico cada vez mais orientado por agilidade e responsabilidade social, a empresa que liderar essa
# transição ganhará vantagem competitiva sustentável, enquanto contribui para uma sociedade mais saudável e menos
# impactada ambientalmente. A escolha não é apenas “boa prática”; é **necessária** para quem deseja prosperar no
# futuro do trabalho.
#
# **Adote a semana de 4 dias hoje e colha os benefícios de amanhã.**

# %% [markdown]
# ### Expansão Técnica

# %%
system_prompt = """
Você é um instrutor técnico especializado em ciência de dados.
Expanda conceitos explicando:
1) Como funciona na prática
2) Exemplos de código quando útil
3) Casos de uso aplicados em empresas
4) Boas práticas de implementação
"""

user_prompt = """
Expanda este conceito técnico:
"Aplicação de modelos preditivos em análise de churn de clientes."
"""

response_technical = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("\n=== EXPANSÃO TÉCNICA ===")
print(response_technical.choices[0].message.content)
# Out:
# === EXPANSÃO TÉCNICA ===
# ## Aplicação de Modelos Preditivos em Análise de Churn de Clientes
# *(Como prever quem vai abandonar o seu serviço e agir antes que isso aconteça)*
#
# ---
#
# ### 1️⃣ Como funciona na prática
#
# | Etapa | O que acontece | Por que é importante |
# |-------|----------------|----------------------|
# | **1. Definição do problema** | Transformar “churn” em uma variável **binária** (`1 = cliente que cancelou`, `0 =
# cliente ativo`). | Clarifica o objetivo e permite mensurar o sucesso do modelo (ex.: taxa de acurácia, recall). |
# | **2. Coleta de dados** | Extrair informações de múltiplas fontes: CRM, logs de uso, tickets de suporte, dados
# financeiros, interações de marketing, etc. | O churn costuma ser influenciado por fatores comportamentais,
# transacionais e de relacionamento. |
# | **3. Integração e limpeza** | Unir tabelas (join por `customer_id`), tratar valores ausentes, remover
# duplicidades, padronizar tipos. | Dados sujos geram viés e reduzem a performance do modelo. |
# | **4. Feature Engineering** | - **Recência, frequência e valor (RFM)** <br> - **Engajamento**: número de logins,
# tempo médio de sessão, número de funcionalidades usadas <br> - **Indicadores de satisfação**: NPS, tickets abertos,
# tempo de resposta <br> - **Variáveis temporais**: churn nos últimos 30/90 dias, sazonalidade <br> - **Encoding** de
# variáveis categóricas (One‑Hot, Target Encoding) <br> - **Escalonamento** (StandardScaler, MinMax) | As variáveis
# criadas são a “matéria‑prima” que o algoritmo usa para encontrar padrões. |
# | **5. Tratamento de desbalanceamento** | Técnicas como **undersampling**, **oversampling** (SMOTE, ADASYN) ou
# ajuste de **class_weight** nos algoritmos. | Em churn, a classe “churn” costuma ser minoritária (5‑15 %). Sem
# balanceamento, o modelo pode simplesmente prever “não churn”. |
# | **6. Seleção e treinamento de modelos** | Algoritmos típicos: <br> - **Logistic Regression** (baseline,
# interpretável) <br> - **Tree‑based**: Random Forest, Gradient Boosting (XGBoost, LightGBM, CatBoost) <br> -
# **Neural Networks** (para grandes volumes e interações complexas) | Cada algoritmo tem trade‑offs entre
# performance, interpretabilidade e custo computacional. |
# | **7. Avaliação** | Métricas adequadas ao desequilíbrio: **Recall (sensibilidade)**, **Precision**, **F1‑Score**,
# **AUC‑ROC**, **PR‑AUC**. Também pode usar **confusion matrix** e **lift chart**. | Em churn, perder um cliente
# (falso‑negativo) costuma ser mais caro que acionar um cliente que não vai churnar (falso‑positivo). |
# | **8. Interpretação** | - **Coeficientes** (LogReg) <br> - **Feature importance** (Tree) <br> - **SHAP / LIME**
# para explicabilidade local/global. | Permite validar se o modelo está usando variáveis de negócio relevantes e
# ganhar confiança das áreas de produto/marketing. |
# | **9. Deploy** | - **Batch scoring** (gerar scores nightly e armazenar em data‑warehouse). <br> - **Real‑time
# scoring** (API REST, modelo em Docker/Kubernetes). <br> - **Orquestração** (Airflow, Prefect) para pipelines de
# atualização. | O modelo só gera valor quando suas previsões são consumidas por processos de retenção. |
# | **10. Ação e monitoramento** | - **Campanhas de retenção** (ofertas, contato proativo). <br> - **Feedback loop**:
# registrar se a ação evitou o churn e alimentar o modelo. <br> - **Drift detection** (monitorar mudança na
# distribuição de features ou performance). | Garante que o modelo continue relevante ao longo do tempo e que a
# estratégia de retenção seja mensurável. |
#
# ---
#
# ### 2️⃣ Exemplos de código (Python)
#
# > **Pré‑requisitos**
# ```bash
# pip install pandas numpy scikit-learn imbalanced-learn xgboost shap matplotlib seaborn
# ```
#
# #### 2.1. Carregamento e preparação básica
#
# ```python
# import pandas as pd
# import numpy as np
#
# # Exemplo: tabela de transações + tabela de clientes
# df_trans = pd.read_parquet('transactions.parquet')
# df_cust  = pd.read_parquet('customers.parquet')
#
# # Unindo por customer_id
# df = df_cust.merge(df_trans, on='customer_id', how='left')
# ```
#
# #### 2.2. Feature Engineering (RFM + engajamento)
#
# ```python
# # Data de referência (último dia disponível)
# ref_date = pd.Timestamp('2025-09-30')
#
# # Recência
# df['recency'] = (ref_date - df['last_purchase_date']).dt.days
#
# # Frequência
# freq = df.groupby('customer_id')['order_id'].nunique().rename('frequency')
# df = df.join(freq, on='customer_id')
#
# # Valor Monetário
# monet = df.groupby('customer_id')['order_amount'].sum().rename('monetary')
# df = df.join(monet, on='customer_id')
#
# # Engajamento (ex.: número de logins nos últimos 30 dias)
# logins = pd.read_parquet('logins.parquet')
# logins_30 = logins[logins['login_ts'] >= ref_date - pd.Timedelta(days=30)]
# eng = logins_30.groupby('customer_id')['login_ts'].count().rename('logins_30d')
# df = df.join(eng, on='customer_id')
# ```
#
# #### 2.3. Definição da variável alvo
#
# ```python
# # Supondo que a coluna churn_date seja nula para clientes ativos
# df['churn'] = np.where(df['churn_date'].notna() &
#                        (df['churn_date'] <= ref_date), 1, 0)
# ```
#
# #### 2.4. Tratamento de desbalanceamento (SMOTE)
#
# ```python
# from imblearn.over_sampling import SMOTE
# from sklearn.model_selection import train_test_split
#
# X = df[['recency', 'frequency', 'monetary', 'logins_30d',
#         'age', 'contract_type', 'monthly_fee']].fillna(0)
# y = df['churn']
#
# # Codificação de variáveis categóricas
# X = pd.get_dummies(X, columns=['contract_type'], drop_first=True)
#
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, stratify=y, random_state=42)
#
# sm = SMOTE(random_state=42)
# X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
# ```
#
# #### 2.5. Treinamento de um modelo Gradient Boosting (XGBoost)
#
# ```python
# import xgboost as xgb
# from sklearn.metrics import roc_auc_score, classification_report
#
# model = xgb.XGBClassifier(
#     n_estimators=300,
#     max_depth=5,
#     learning_rate=0.05,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     eval_metric='auc',
#     scale_pos_weight = (y_train_res == 0).sum() / (y_train_res == 1).sum(),
#     n_jobs=-1,
#     random_state=42
# )
#
# model.fit(X_train_res, y_train_res,
#           eval_set=[(X_test, y_test)],
#           early_stopping_rounds=30,
#           verbose=False)
#
# # Avaliação
# y_pred_proba = model.predict_proba(X_test)[:, 1]
# print('AUC‑ROC:', roc_auc_score(y_test, y_pred_proba))
# print(classification_report(y_test, model.predict(X_test)))
# ```
#
# #### 2.6. Interpretação com SHAP
#
# ```python
# import shap
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)
#
# # Plot de importância global
# shap.summary_plot(shap_values, X_test, plot_type='bar')
# # Plot de dependência (ex.: recency)
# shap.dependence_plot('recency', shap_values, X_test)
# ```
#
# #### 2.7. Deploy simples como API Flask
#
# ```python
# # save model
# import joblib
# joblib.dump(model, 'churn_model.pkl')
#
# # app.py
# from flask import Flask, request, jsonify
# import joblib, pandas as pd
#
# app = Flask(__name__)
# model = joblib.load('churn_model.pkl')
# features = ['recency','frequency','monetary','logins_30d','age',
#             'contract_type_monthly','contract_type_yearly','monthly_fee']
#
# @app.route('/predict', methods=['POST'])
# def predict():
#     data = request.get_json(force=True)          # dict
#     df = pd.DataFrame().fillna(0)
#     prob = model.predict_proba(df)[:,1][0]
#     return jsonify({'churn_probability': float(prob)})
#
# if __name__ == '__main__':
#     app.run(host='0.0.0.0', port=5000)
# ```
#
# > **Obs.:** Em produção, use **FastAPI**, Docker, e orquestre com **Kubernetes** ou **AWS SageMaker** para
# escalabilidade.
#
# ---
#
# ### 3️⃣ Casos de uso aplicados em empresas
#
# | Setor | Problema de churn | Como o modelo foi usado | Resultado típico |
# |-------|-------------------|------------------------|------------------|
# | **Telecom** | Clientes que cancelam plano pós‑promoção. | Modelos preditivos alimentam o **CRM**; equipe de
# retenção recebe lista de “high‑risk” e oferece upgrade ou desconto. | Redução de churn em **12‑18 %** ao ano;
# aumento de ARPU (Revenue per User) em **5 %**. |
# | **SaaS (Software as a Service)** | Usuários que deixam de renovar assinatura anual. | Score de churn integrado ao
# **pipeline de renovação**; e‑mails automáticos com trial de nova feature para clientes com risco > 0,7. | **30 %**
# de clientes de risco converteram a renovação; churn geral caiu de **8 %** para **4,5 %**. |
# | **Banco / FinTech** | Clientes que fecham conta ou deixam de usar cartão. | Modelos de risco de churn alimentam o
# **contact center**; agentes recebem scripts personalizados (ex.: aumento de limite, programa de recompensas). |
# Aumento de **retenção de 6 %** em contas de alta renda; diminuição de churn de cartões em **15 %**. |
# | **E‑commerce** | Clientes que não retornam após a primeira compra. | Score usado para **campanhas de
# remarketing** (Google Ads, e‑mail) com cupons personalizados. | **ROAS** (Return on Ad Spend) melhorou em **2,3×**;
# churn de compradores de primeira compra caiu de **45 %** para **28 %**. |
# | **Streaming / mídia** | Cancelamento de assinatura mensal. | Modelo alimenta o **recommendation engine**:
# usuários com risco alto recebem sugestões de conteúdo “high‑engagement”. | Redução de churn em **9 %**; aumento de
# tempo médio de visualização em **12 %**. |
#
# > **Insight comum:** a maior parte do valor vem não só da previsão, mas da **ação** (ofertas, contato proativo,
# melhoria de produto) que a empresa implementa com base no score.
#
# ---
#
# ### 4️⃣ Boas práticas de implementação
#
# #### 4.1. Estratégia de dados
# 1. **Data Governance** – Documente origem, frequência de atualização e políticas de privacidade (LGPD/GDPR).
# 2. **Feature Store** – Centralize features calculadas (ex.: RFM) para garantir consistência entre treinamento e
# scoring.
# 3. **Versionamento** – Use DVC, Delta Lake ou LakeFS para versionar datasets e pipelines.
#
# #### 4.2. Modelagem
# 1. **Baseline simples** – Comece com Logistic Regression; ele serve como referência de interpretabilidade.
# 2. **Cross‑validation estratificado** – Em churn, preserve a proporção de classes em cada fold.
# 3. **Hiper‑parametrização** – GridSearch/RandomSearch ou **Optuna** para encontrar a melhor combinação (ex.:
# `max_depth`, `learning_rate`).
# 4. **Ensemble** – Combine modelos (stacking) para ganhar robustez, mas avalie o custo de inferência.
#
# #### 4.3. Métricas e validação
# - **Recall > 0,7** costuma ser o objetivo (capturar a maioria dos clientes que vão churnar).
# - **Precision** deve ser monitorada para evitar “spam” de ofertas a clientes que não vão churnar.
# - **Lift / Gains Chart** – Mostra o ganho de negócio ao segmentar os top‑X% de risco.
#
# #### 4.4. Interpretabilidade e compliance
# - **SHAP** para explicar decisões individuais a gestores e áreas regulatórias.
# - **Feature importance** deve ser revisado periodicamente; variáveis que “desaparecem” podem indicar mudança de
# comportamento do cliente.
#
# #### 4.5. Deploy e monitoramento
# | Aspecto | Como fazer |
# |--------|------------|
# | **Batch scoring** | Agende jobs (Airflow, Prefect) que leiam a feature store, gerem scores e escrevam em
# `customer_score` table. |
# | **Real‑time** | Exponha modelo como API (FastAPI) com **latência < 100 ms**; use **model server** (Seldon,
# TorchServe, KFServing). |
# | **Drift detection** | Calcule **Population Stability Index (PSI)** ou **Kolmogorov‑Smirnov** entre distribuição
# de features atuais e de treinamento. |
# | **A/B testing** | Divida a base em *control* (sem ação) e *treatment* (recebe campanha baseada no score). Meça
# churn, receita e custo da campanha. |
# | **Feedback loop** | Registre se a ação (ex.: oferta) foi aceita e se o cliente permaneceu. Use esses rótulos para
# re‑treinar o modelo a cada 30‑60 dias. |
#
# #### 4.6. Governança de modelo
# - **Model Registry** (MLflow, Weights & Biases) para armazenar artefatos, métricas e lineage.
# - **Política de aprovação** – Modelos só entram em produção após revisão de *Data Scientist*, *Product Owner* e
# *Compliance*.
# - **Rollback** – Mantenha a versão anterior pronta para ser reativada caso a nova apresente degradação.
#
# #### 4.7. Ética e privacidade
# - Remova ou anonimiza dados sensíveis (CPF, endereço) antes de treinar.
# - Avalie **bias**: verifique se o modelo não penaliza grupos demográficos (ex.: idade, região).
# - Documente a finalidade do modelo e ofereça canal de contestação ao cliente, conforme exigências regulatórias.
#
# ---
#
# ## 📌 Resumo rápido (cheat‑sheet)
#
# ```text
# 1️⃣ Definir churn → binário
# 2️⃣ Unir dados (CRM, logs, finanças)
# 3️⃣ Feature Eng.: RFM, engajamento, NPS, tickets
# 4️⃣ Tratar desbalanceamento (SMOTE / class_weight)
# 5️⃣ Treinar baseline (LogReg) → avançado (XGBoost, LightGBM)
# 6️⃣ Avaliar: AUC‑ROC, Recall, PR‑AUC, Lift
# 7️⃣ Interpretar: SHAP, coeficientes
# 8️⃣ Deploy: batch (Airflow) ou real‑time (FastAPI + Docker)
# 9️⃣ Ação: campanhas, ofertas, contato proativo
# 🔟 Monitorar: drift, performance, feedback loop
# ```
#
# ---
#
# ### Próximos passos recomendados para sua organização
#
# 1. **Mapeamento de fontes** – Liste todos os sistemas que contêm sinais de comportamento do cliente.
# 2. **PoC de 4‑6 semanas** – Use um subset de dados (últimos 6 meses) para criar um modelo de churn básico e validar
# a pipeline de scoring.
# 3. **Construir Feature Store** – Centralize cálculos de RFM, engajamento e NPS.
# 4. **Implementar campanha piloto** – Segmente os top‑10 % de risco e teste duas estratégias de retenção (desconto
# vs. upgrade).
# 5. **Métricas de negócio** – Defina OKRs: “Reduzir churn em X % nos próximos 3 meses” e “Aumentar taxa de aceitação
# de ofertas em Y %”.
#
# Com esses blocos bem alinhados, a análise preditiva de churn deixa de ser apenas um modelo estatístico e passa a
# ser um **motor de decisão** que gera receita e fortalece o relacionamento com o cliente. 🚀

# %% [markdown]
# ### Expansão de Outline

# %%
outline_prompt = """
Expanda este outline em um artigo curto e completo:

TÍTULO: "Tendências em Educação Digital para 2026"

OUTLINE:
1. Introdução - Acelerando a transformação educacional
2. Plataformas personalizadas de aprendizagem
3. Realidade aumentada e gamificação
4. Aprendizado contínuo para profissionais
5. Desafios e riscos
6. Conclusão - O futuro da educação
"""

response_outline = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": outline_prompt}],
    temperature=0.6
)

print("\n=== EXPANSÃO DE OUTLINE ===")
print(response_outline.choices[0].message.content)
# Out:
# === EXPANSÃO DE OUTLINE ===
# **Tendências em Educação Digital para 2026**
#
# ---
#
# ### 1. Introdução – Acelerando a transformação educacional
#
# Nos últimos cinco anos, a educação digital passou de uma alternativa pontual para se tornar a espinha dorsal dos
# sistemas de ensino em todo o mundo. A pandemia, o avanço das infraestruturas de conectividade e a democratização de
# tecnologias como inteligência artificial (IA) e realidade estendida (XR) criaram um ambiente propício à inovação
# acelerada. Em 2026, a expectativa não é apenas digitalizar o que já existia, mas repensar *como* aprendemos,
# *quando* aprendemos e *para quem* o aprendizado é direcionado.
#
# ---
#
# ### 2. Plataformas personalizadas de aprendizagem
#
# #### 2.1 Inteligência artificial como tutor
# - **Algoritmos adaptativos** analisam o histórico de desempenho, estilo cognitivo e ritmo de cada estudante,
# ajustando o conteúdo em tempo real.
# - **Chatbots avançados** (baseados em LLMs como GPT‑4/5) oferecem explicações instantâneas, feedback detalhado e
# sugestões de recursos complementares.
#
# #### 2.2 Ecossistemas integrados
# - **Learning Experience Platforms (LXP)** substituem os tradicionais LMS ao combinar curadoria de conteúdo, redes
# sociais internas e analytics avançados.
# - **Micro‑credenciais** (badges, NFTs) são emitidas automaticamente ao concluir módulos, facilitando a construção
# de portfólios digitais reconhecidos pelo mercado.
#
# #### 2.3 Dados como motor de decisão
# - Painéis de **learning analytics** permitem que gestores identifiquem lacunas de aprendizagem, prevejam evasões e
# personalizem intervenções pedagógicas antes mesmo que o aluno perceba a dificuldade.
#
# ---
#
# ### 3. Realidade aumentada e gamificação
#
# #### 3.1 Realidade aumentada (AR) e realidade mista (MR)
# - **Laboratórios virtuais**: estudantes de química, biologia ou engenharia realizam experimentos seguros e custosos
# em ambientes 3‑D projetados sobre a realidade física.
# - **Visitas imersivas**: história e geografia ganham vida com reconstruções de sítios arqueológicos ou ecossistemas
# que podem ser explorados via smartphones ou óculos MR.
#
# #### 3.2 Gamificação avançada
# - **Mecânicas baseadas em narrativa** criam histórias contínuas onde o progresso acadêmico desbloqueia capítulos,
# personagens e missões.
# - **Sistemas de pontuação dinâmicos** utilizam algoritmos de IA para equilibrar desafios, evitando a
# “sobre‑gamificação” que pode gerar fadiga.
#
# #### 3.3 Impacto comprovado
# Estudos de 2024‑2025 mostram aumento de 23 % na retenção de conceitos quando o conteúdo é entregue via AR +
# gamificação, comparado a métodos tradicionais.
#
# ---
#
# ### 4. Aprendizado contínuo para profissionais
#
# #### 4.1 Upskilling e reskilling como rotina
# - **Learning‑as‑a‑Service (LaaS)**: empresas assinam catálogos de cursos atualizados mensalmente, integrados ao
# fluxo de trabalho (ex.: módulos dentro de ferramentas de CRM).
# - **Mentoria baseada em IA**: sistemas recomendam mentores humanos ou “co‑pilotos” de IA conforme a trajetória de
# carreira do colaborador.
#
# #### 4.2 Micro‑learning e aprendizado just‑in‑time
# - Conteúdos de 5‑10 minutos, entregues via notificações push ou assistentes de voz, permitem que profissionais
# aprendam no momento em que a necessidade surge (ex.: “como usar a nova função do SAP”).
#
# #### 4.3 Certificações dinâmicas
# - **Credenciais baseadas em competências** são avaliadas por avaliações automatizadas que medem desempenho real,
# não apenas tempo de estudo.
# - **Blockchain** garante a autenticidade e rastreabilidade das certificações, facilitando a mobilidade
# internacional de talentos.
#
# ---
#
# ### 5. Desafios e riscos
#
# | Desafio | Impacto | Estratégias de mitigação |
# |---|---|---|
# | **Desigualdade de acesso** | Regiões com conectividade limitada podem ficar ainda mais atrasadas. | Investimento
# público‑privado em broadband 5G/6G; modelos offline‑first que sincronizam quando houver conexão. |
# | **Privacidade e segurança de dados** | Grandes volumes de dados sensíveis de estudantes e profissionais. |
# Criptografia end‑to‑end, compliance com GDPR/ LGPD, auditorias regulares de IA. |
# | **Dependência tecnológica** | Falhas de plataforma podem interromper o aprendizado. | Arquiteturas de nuvem
# resilientes, planos de contingência e backup local. |
# | **Viés algorítmico** | Algoritmos podem reproduzir preconceitos existentes. | Treinamento de IA com datasets
# diversificados, auditorias de fairness, supervisão humana. |
# | **Sobrecarga cognitiva** | Excesso de recursos interativos pode distrair. | Design centrado no usuário, limites
# de tempo de gamificação, feedback de usabilidade constante. |
#
# ---
#
# ### 6. Conclusão – O futuro da educação
#
# Em 2026, a educação digital deixará de ser “uma ferramenta” para se tornar **um ecossistema inteligente** que
# entende o aprendiz como indivíduo, oferece experiências imersivas e se alinha às demandas do mercado em tempo real.
# As plataformas personalizadas, a realidade aumentada e a gamificação criarão ambientes de aprendizagem mais
# engajadores, enquanto o aprendizado contínuo se consolidará como a norma para profissionais de todas as áreas.
#
# Entretanto, o sucesso desse futuro depende de políticas que garantam inclusão digital, de governança ética da IA e
# de um design pedagógico que priorize a clareza sobre o brilho tecnológico. Quando esses pilares forem equilibrados,
# a transformação educacional não será apenas mais rápida – será **mais justa, mais eficaz e verdadeiramente centrada
# no ser humano**.
#
# ---
#
# *Autor: [Seu Nome]*
# *Especialista em Tecnologia Educacional*
# *Publicado em: Outubro de 2025*
